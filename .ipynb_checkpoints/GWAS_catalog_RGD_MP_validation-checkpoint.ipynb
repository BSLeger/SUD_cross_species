# %% [markdown]
# purpose: sister notebook to EFO_analysis_GWAS_cat.ipynb. Exploratory factor ontology is the structure used by the GWAS catalog, but it is difficult to parse, so the people at RGD have mapped the EFO URI traits into the mammalian phenotype ontology (as well as other ontologies, found here: https://download.rgd.mcw.edu/ontology/mappings/).
#
# The purpose of this notebook is to use the RGD's mapping to test validation for externalizing-locomotor network using the RGD's mappings to the MP, so that it parallels the MGI validation. Mapping download link for MP specifically: https://download.rgd.mcw.edu/ontology/mappings/efo_mp_rgd.sssom.tsv.txt

# %% [markdown]
# # set-up

# %%
import os
os.chdir('/tscc/projects/ps-palmer/brittany/ddot')
import ddot
from netcoloc import netprop_zscore, netprop, network_colocalization, validation

# %%
import pandas as pd
import obonet as obo
import networkx as nx
import ndex2
import numpy as np
import matplotlib.pyplot as plt
from upsetplot import plot as upplot
from upsetplot import from_contents
from upsetplot import UpSet
import scipy.stats as stats
from adjustText import adjust_text
import requests

# %%
os.chdir('/tscc/projects/ps-palmer/brittany/SUD_cross_species/')

# %%
save_fig=True

# %% [markdown]
# # functions

# %%
UUIDs={
    'PCNet2.0':'d73d6357-e87b-11ee-9621-005056ae23aa',
    'PCNet2.1':'e9c574f4-e87a-11ee-9621-005056ae23aa',
    'PCNet2.2':'8b4b54fa-e87d-11ee-9621-005056ae23aa'
}

# %%
def import_seedgenes(path,pcol='P',gene_col='GENE NAME',delim='comma', cutoff=None):
    if delim=='comma':
        df=pd.read_csv(path,sep=',')
    else:
        df=pd.read_csv(path,sep='\t')
    if pcol==None:
        print('pvalue column not specified- all genes will be used')
        cutoff=None
    if cutoff=='bonferroni':
        df=df[df[pcol]<0.05/len(df)]
    elif cutoff=='FDR_05':
        df=df[df[pcol]<0.05]
    else:
        print('cutoff not defined/custom- using all genes ')
        df=df
    print(df.head())
    return(df)

# %%
def import_interactome(interactome_name=None, UUIDs=UUIDs,ndex_user=None, ndex_password=None,UUID=None):
    """
    Imports a gene interactome from the NDEx database and returns it as a NetworkX graph object. Optionally,
    the function allows for importing using a unique identifier (UUID) or by an interactome name.

    The function checks if the interactome name provided corresponds to a predefined dictionary of UUIDs. If it does, it
    retrieves the network using the specified credentials. If an interactome name is not provided but a UUID is,
    it retrieves the network using the provided UUID. The nodes of pcnet_v14 are relabelled by their gene name rather than ID number.

    Parameters:
    - interactome_name (str, optional): The name of the interactome as defined in the UUIDs dictionary. If not provided
      but a UUID is, the interactome associated with the UUID is imported instead.
    - ndex_user (str, optional): The NDEx account username for accessing private networks.
    - ndex_password (str, optional): The NDEx account password for accessing private networks.
    - UUID (str, optional): A specific UUID to directly download an interactome from NDEx if the interactome name is not used.

    Returns:
    networkx.Graph: A graph object representing the interactome. Nodes and edges represent genes and their interactions, respectively.

    Notes:
    - The function uses the NDEx2 Python client and requires Internet access to NDEx's servers.
    - Depending on the access rights of the NDEx account, private or public interactomes can be retrieved.
    - The function prints the number of nodes and edges of the imported graph for diagnostic purposes.

    Raises:
    - ValueError: If neither an interactome name nor a UUID is provided.
    """    
    interactome_uuid=UUIDs[interactome_name]
    print(interactome_name)
    ndex_server='public.ndexbio.org'
    #import network based on provided interactome key
    if (interactome_name in UUIDs.keys()):
        graph = ndex2.create_nice_cx_from_server(
                    ndex_server, 
                    username=ndex_user, 
                    password=ndex_password, 
                    uuid=interactome_uuid
                ).to_networkx()
        if (interactome_name=='pcnet_v14'):
            graph=nx.relabel_nodes(graph, nx.get_node_attributes(graph, 'HGNC Symbol'))
        # print out interactome num nodes and edges for diagnostic purposes
        print('number of nodes:')
        print(len(graph.nodes))
        print('\nnumber of edges:')
        print(len(graph.edges))
        return(graph)
    elif(interactome_name==None & UUID!=None):
        print('using novel UUID. For UUIDs used in this study, see UUID_dict')
        graph = ndex2.create_nice_cx_from_server(
            ndex_server, 
            username=ndex_user, 
            password=ndex_password, 
            uuid=UUID
        ).to_networkx()
        # print out interactome num nodes and edges for diagnostic purposes
        print('number of nodes:')
        print(len(graph.nodes))
        print('\nnumber of edges:')
        print(len(graph.edges))
        return(graph)
    else:
        print('UUID/interactome name not provided- please provide either to import interactome.')

# %%
def format_catalog(catalog=None):
	try:
		#make all annotations lowercase for consistency for querying
		catalog['MAPPED_TRAIT']=catalog['MAPPED_TRAIT'].str.lower()
		catalog['DISEASE/TRAIT']=catalog['DISEASE/TRAIT'].str.lower()
		#filter for genes that were mapped
		mapped=catalog[~catalog['MAPPED_GENE'].isna()]
		mapped=mapped[~mapped['MAPPED_TRAIT'].isna()]
		mapped=mapped[['MAPPED_GENE','MAPPED_TRAIT','DISEASE/TRAIT','PUBMEDID']]
		mapped.columns=['GENE','MAPPED_TRAIT','DISEASE/TRAIT','PUBMEDID']
		#filter for genes that were reported
		rep=catalog[~catalog['REPORTED GENE(S)'].isna()]
		rep=rep[~rep['MAPPED_TRAIT'].isna()]
		rep=rep[~rep['REPORTED GENE(S)'].str.contains('Intergenic')]
		rep=rep[['REPORTED GENE(S)','MAPPED_TRAIT','DISEASE/TRAIT','PUBMEDID']]
		rep.columns=['GENE','MAPPED_TRAIT','DISEASE/TRAIT','PUBMEDID']
		cat=pd.concat([rep, mapped])
		cat['GENE']=cat['GENE'].str.split('; ')
		cat=cat.explode('GENE')
		cat=cat[~(cat['GENE'].str.contains('mapped'))]
		cat['GENE']=cat['GENE'].str.split(', ')
		cat=cat.explode('GENE')
		cat['GENE']=cat['GENE'].str.split(' - ')
		cat=cat.explode('GENE')
		cat['GENE']=cat['GENE'].astype('str')
		cat=cat[~(cat['GENE'].str.contains('intergenic'))]
		cat['TRAIT']=cat['MAPPED_TRAIT'] + ": " +cat['DISEASE/TRAIT']+ " (PMID: "+(cat['PUBMEDID'].astype(str))+")"
		cat=cat.dropna()
		return(cat)
	except:
		print('please add gwas catalog file.')

# %%
def calculate_enrichment(t, coloc_dict_cat, k):
    
    # Extract the genes associated with the parent term

    # Calculate values for the contingency table
    M = len(coloc_dict_cat['graph'])  # Population size: genes in PCNet annotated in the GWAS catalog
    n = len(coloc_dict_cat['graph'].intersection(t))  # Genes in PCNet annotated for the trait of interest
    N = len(coloc_dict_cat['net'])  # Genes in the network annotated in the GWAS catalog
    x = len(coloc_dict_cat['net'].intersection(t))  # Genes in network annotated for the trait of interest

    # Build contingency table
    contingency_table = [
        [x, N - x],
        [n - x, M - N - (n - x)]
    ]

    # Perform Fisher's exact test
    odds_ratio, p_intersect = stats.fisher_exact(contingency_table, alternative='greater')
    gene_list=t.intersection(coloc_dict_cat['net'])
    # Create the results dictionary
    print(f"Enrichment of network nodes in genes in the GWAS catalog annotated for {k}: p={p_intersect}")
    print(f"Odds ratio: OD={odds_ratio}")
    print(f"Number of annotated genes in PCNet: {len(t.intersection(coloc_dict_cat['graph']))}")
    print(f"Number of annotated genes in network: {len(t.intersection(coloc_dict_cat['net']))}\n")

    return  odds_ratio, p_intersect, gene_list

# %%
def import_MPO_description(url='http://www.informatics.jax.org/downloads/reports/MPheno_OBO.ontology'):
    """
    Function to parse and load mouse phenotype ontology, using DDOT's ontology module
    modified from NetColoc

    :param url: URL containing MPO ontology file
    :type url: str
    :return: MPO parsed using DDOT
    :rtype: :py:class:`pd.DataFrame`
    """

    # download the mammalian phenotype ontology, parse with ddot
    r = requests.get(url,allow_redirects=True)
    open('MPheno_OBO.ontology','wb').write(r.content)

    ddot.parse_obo('MPheno_OBO.ontology',
                   'parsed_mp.txt',
                  'id2name_mp.txt',
                  'id2namespace_mp.txt',
                  'altID_mp.txt')


    MP2desc = pd.read_csv('id2name_mp.txt',sep='\t',
                          names=['MP','description'],index_col='MP')

    MP2desc=MP2desc.loc[MP2desc.index.dropna()] # drop NAN from index
    print(len(MP2desc))
    return(MP2desc)

# %% [markdown]
# ## FUNCTION TO GET DESCENDENTS FROM EFO NETWORK

# %%
#return list set of traits in EFO ontology including parent- reported by name
def return_efo_descendents_name(graph,id_to_name, term):
    l=list(sorted(id_to_name[subterm] for subterm in nx.ancestors(graph, term))) #descendents get subterms- not sure why but I tested it and OBONET says so as well
    l.append(id_to_name[term])
    return list(set(l))

# %%
#return list set of traits in EFO ontology including parent- reported by name
def return_efo_ancestors_name(graph,id_to_name, term):
    print('getting ancestors for '+term+' : '+id_to_name[term])
    l=list((id_to_name[supterm] for supterm in nx.descendants(graph, term))) #descendents get superterms- not sure why
    #l.append(id_to_name[term])
    return list(set(l))

# %% [markdown]
# # import network genelists

# %% [markdown]
# ## Interactome Set-up

# %% [markdown]
# pcnet2- versions
# from wright et al. 2024 preprint:
# PCNet 2.0= best-performing ranked composite (top 15 interactomes, 3.85M interactions)
# PCNet 2.1= top 8 interactomes, 1.75M interactions
# PCNet 2.2= top 10 co-citation-free interactomes, 3.32M interactions

# %%
interactome_name='PCNet2.0'

# %%
graph=import_interactome(interactome_name)
# Out:
# PCNet2.0
# number of nodes:
# 19267
#
# number of edges:
# 3852119

# %%
all_nodes=list(graph.nodes())

# %% [markdown]
# ## import NPS scores and seed genes

# %%
mag_dir='magma/seed_genes/'
file_dict={
    'loco':mag_dir+'loco_win10_annot.tsv',
    'loco_gsem':mag_dir+'loco_gsem_annot.tsv',
    'ext_munged':mag_dir+'ext_munged_annot.tsv',
    'ext':mag_dir+'ext_orig_annot.tsv'
}

# %%
seed_dict={}

# %%
loco=pd.read_csv(file_dict['loco'],sep='\t')
loco_bonf_cut=2.6389402016150313e-06 #calculated in define_seed_genes_orthologs- from raw magma results before adding in ortholog info
seed_dict['loco_FDR']=(set(loco[loco['Q']<0.05]['HM_ORTHO']))
seed_dict['loco_bonf']=(set(loco[loco['P']<loco_bonf_cut]['HM_ORTHO']))

# %%
#locomotor- gsem common factor
loco_gsem=pd.read_csv(file_dict['loco_gsem'],sep='\t')
loco_gsem_bonf_cut=2.650129856362962e-06 #calculated in define_seed_genes_orthologs- from raw magma results before adding in ortholog info
seed_dict['loco_gsem_FDR']=(set(loco_gsem[loco_gsem['Q']<0.05]['HM_ORTHO']))
seed_dict['loco_gsem_bonf']=(set(loco_gsem[loco_gsem['P']<loco_gsem_bonf_cut]['HM_ORTHO']))

# %%
ext=pd.read_csv(file_dict['ext'],sep='\t')
ext_bonf_cut=0.05/len(ext) # no ortholog adding, so can calculate from this table
seed_dict['ext_FDR']=(set(ext[ext['Q']<0.05]['GENE']))
seed_dict['ext_bonf']=(set(ext[ext['P']<ext_bonf_cut]['GENE']))

# %%
'''ext=pd.read_csv(file_dict['ext'],sep='\t')
ext_bonf_cut=0.05/len(ext) # no ortholog adding, so can calculate from this table
seed_dict['ext_munged_FDR']=(set(ext[ext['Q']<0.05]['GENE']))
seed_dict['ext_munged_bonf']=(set(ext[ext['P']<ext_bonf_cut]['GENE']))'''
# Out:
# "ext=pd.read_csv(file_dict['ext'],sep='\t')\next_bonf_cut=0.05/len(ext) # no ortholog adding, so can calculate from this table\nseed_dict['ext_munged_FDR']=(set(ext[ext['Q']<0.05]['GENE']))\nseed_dict['ext_munged_bonf']=(set(ext[ext['P']<ext_bonf_cut]['GENE']))"

# %%
seed_dict['ext_top500']=set(ext[(ext['GENE'].isin(all_nodes))].nsmallest(500,'P')['GENE'])

# %%
seed_dict.keys()
# Out:
# dict_keys(['loco_FDR', 'loco_bonf', 'loco_gsem_FDR', 'loco_gsem_bonf', 'ext_FDR', 'ext_bonf', 'ext_top500'])

# %%
NPS_dict={}
for k in seed_dict.keys():
    for u in UUIDs.keys():
        p=('network_scores/'+k+'_'+u+'_zscore.tsv')
        if os.path.isfile(p):
            t=pd.read_csv('network_scores/'+k+'_'+u+'_zscore.tsv',header=None, sep='\t')
            t.index=t[0]
            t=t.drop(columns=[0])
            t=t[1].squeeze()
            t = pd.DataFrame({'z':t})
            NPS_dict[k+'_'+u]=t

# %%
NPS_dict_series={}
for k in seed_dict.keys():
    for u in UUIDs.keys():
        p=('network_scores/'+k+'_'+u+'_zscore.tsv')
        if os.path.isfile(p):
            t=pd.read_csv('network_scores/'+k+'_'+u+'_zscore.tsv',header=None, sep='\t')
            t.index=t[0]
            t=t.drop(columns=[0])
            #t=t[1].squeeze()
            #t = pd.DataFrame({'z':t})
            NPS_dict_series[k+'_'+u]=t

# %%
NPS_dict.keys()
# Out:
# dict_keys(['loco_FDR_PCNet2.0', 'loco_FDR_PCNet2.2', 'loco_bonf_PCNet2.0', 'loco_bonf_PCNet2.2', 'loco_gsem_FDR_PCNet2.0', 'loco_gsem_FDR_PCNet2.1', 'loco_gsem_FDR_PCNet2.2', 'loco_gsem_bonf_PCNet2.0', 'loco_gsem_bonf_PCNet2.1', 'loco_gsem_bonf_PCNet2.2', 'ext_FDR_PCNet2.0', 'ext_FDR_PCNet2.2', 'ext_bonf_PCNet2.0', 'ext_bonf_PCNet2.2', 'ext_top500_PCNet2.0', 'ext_top500_PCNet2.2'])

# %% [markdown]
# ## choose datasets for analysis- put gene lists into dictionary

# %%
cut_single=1.5
cut_comb=3

# %%
cut_r= 'FDR'
#cut_h='bonf'
cut_h=None
trait_r='loco_gsem'
trait_h='ext_top500'

#labels
if cut_h==None:
    label_h=trait_h
else:
    label_h=trait_h+'_'+cut_h
if cut_r==None:
    label_r=trait_r
else:
    label_r=trait_r+'_'+cut_r
#seed genes
seed_r=seed_dict[label_r]
seed_h=seed_dict[label_h]
#NPS scores
NPS_r=NPS_dict[label_r+'_'+interactome_name]
NPS_h=NPS_dict[label_h+'_'+interactome_name]

# %%
NPS_r.merge(NPS_h)
NPS = NPS_h.join(NPS_r, lsuffix="h", rsuffix="r")
NPS = NPS.assign(zhr=NPS.zh * NPS.zr)

# %%
coloc_dict={
    'seed_r':seed_r,
    'seed_h':seed_h,
    'seed_hm':list(set(seed_r).intersection(seed_h)),
    'net':list(NPS[(NPS.zh>cut_single)&(NPS.zr>cut_single)&(NPS.zhr>cut_comb)].index),
    'graph':all_nodes
}

# %% [markdown]
# # import EFO table from GWAS catalog

# %%
#ontology mapping table for GWAS catalog
onto=pd.read_csv('validation_datasets/trait_mappings.txt',sep='\t')

# %%
onto['EFO_term']=onto['EFO URI'].apply(lambda x: x.split('/')[len(x.split('/'))-1])
onto['EFO_term']=onto['EFO_term'].str.replace('_',':')

# %%
onto['Disease trait']=onto['Disease trait'].str.lower()

# %% [markdown]
# # import gwas catalog associations

# %%
gwas_catalog=pd.read_csv('validation_datasets/gwas-catalog_v1.0.2_20240807.tsv',sep='\t',low_memory=False)
cat=format_catalog(gwas_catalog)

# %%
cat=cat.merge(onto, left_on='DISEASE/TRAIT',right_on='Disease trait')

# %% [markdown]
# # import the table mapping of the Mammalian Phenotype ontology to the EFO

# %%
EFO2MP=pd.read_csv('validation_datasets/efo_mp_rgd.sssom.tsv.txt',sep='\t',skiprows=16)

# %%
onto_mp=onto.merge(EFO2MP[['object_id','object_label','subject_id','subject_label']],left_on='EFO_term',right_on='object_id')

# %%
cat=cat.merge(EFO2MP[['object_id','object_label','subject_id','subject_label']],left_on='EFO_term',right_on='object_id')

# %%
len(set(EFO2MP['object_id']))
# Out:
# 209

# %%
len(set(onto_mp['object_id']))
# Out:
# 184

# %%
len(set(onto['EFO_term']))
# Out:
# 15583

# %%
onto_mp
# Out:
#                                           Disease trait         EFO term  \
# 0                                      anorexia nervosa  eating disorder
# 1                  bipolar disorder and eating disorder  eating disorder
# 2                         eating disorder (phecode 305)  eating disorder
# 3                       eating disorder (phecode 305.2)  eating disorder
# 4                   eating disorder in bipolar disorder  eating disorder
# ...                                                 ...              ...
# 1373                             lumbar spinal stenosis  spinal stenosis
# 1374  lumbosacral radicular syndrome or lumbar spina...  spinal stenosis
# 1375                              spinal canal stenosis  spinal stenosis
# 1376                                    spinal stenosis  spinal stenosis
# 1377                      spinal stenosis (phecode 720)  spinal stenosis
#
#                                    EFO URI            Parent term  \
# 0     http://www.ebi.ac.uk/efo/EFO_0005203  Neurological disorder
# 1     http://www.ebi.ac.uk/efo/EFO_0005203  Neurological disorder
# 2     http://www.ebi.ac.uk/efo/EFO_0005203  Neurological disorder
# 3     http://www.ebi.ac.uk/efo/EFO_0005203  Neurological disorder
# 4     http://www.ebi.ac.uk/efo/EFO_0005203  Neurological disorder
# ...                                    ...                    ...
# 1373  http://www.ebi.ac.uk/efo/EFO_0007490          Other disease
# 1374  http://www.ebi.ac.uk/efo/EFO_0007490          Other disease
# 1375  http://www.ebi.ac.uk/efo/EFO_0007490          Other disease
# 1376  http://www.ebi.ac.uk/efo/EFO_0007490          Other disease
# 1377  http://www.ebi.ac.uk/efo/EFO_0007490          Other disease
#
#                                 Parent URI     EFO_term    object_id  \
# 0     http://www.ebi.ac.uk/efo/EFO_0000618  EFO:0005203  EFO:0005203
# 1     http://www.ebi.ac.uk/efo/EFO_0000618  EFO:0005203  EFO:0005203
# 2     http://www.ebi.ac.uk/efo/EFO_0000618  EFO:0005203  EFO:0005203
# 3     http://www.ebi.ac.uk/efo/EFO_0000618  EFO:0005203  EFO:0005203
# 4     http://www.ebi.ac.uk/efo/EFO_0000618  EFO:0005203  EFO:0005203
# ...                                    ...          ...          ...
# 1373  http://www.ebi.ac.uk/efo/EFO_0000408  EFO:0007490  EFO:0007490
# 1374  http://www.ebi.ac.uk/efo/EFO_0000408  EFO:0007490  EFO:0007490
# 1375  http://www.ebi.ac.uk/efo/EFO_0000408  EFO:0007490  EFO:0007490
# 1376  http://www.ebi.ac.uk/efo/EFO_0000408  EFO:0007490  EFO:0007490
# 1377  http://www.ebi.ac.uk/efo/EFO_0000408  EFO:0007490  EFO:0007490
#
#          object_label  subject_id             subject_label
# 0     eating disorder  MP:0001431  abnormal eating behavior
# 1     eating disorder  MP:0001431  abnormal eating behavior
# 2     eating disorder  MP:0001431  abnormal eating behavior
# 3     eating disorder  MP:0001431  abnormal eating behavior
# 4     eating disorder  MP:0001431  abnormal eating behavior
# ...               ...         ...                       ...
# 1373  spinal stenosis  MP:0021170           spinal stenosis
# 1374  spinal stenosis  MP:0021170           spinal stenosis
# 1375  spinal stenosis  MP:0021170           spinal stenosis
# 1376  spinal stenosis  MP:0021170           spinal stenosis
# 1377  spinal stenosis  MP:0021170           spinal stenosis
#
# [1378 rows x 10 columns]

# %% [markdown]
# # import MGI datasets

# %%
MPO_desc=import_MPO_description()
# Out:
# 15364
# /tscc/projects/ps-palmer/brittany/ddot/ddot/Ontology.py:394: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   pd.Series(id2namespace).to_csv(id2namespace_file, sep='\t')

# %%
#import the MPO in graph format
graph = obo.read_obo('http://www.informatics.jax.org/downloads/reports/MPheno_OBO.ontology')
#subset the graph to remove obsolete terms
graph=graph.subgraph(list(set(MPO_desc[~MPO_desc['description'].str.contains('obsolete')].index)))

# %%
#get id from name or name from ID 
id_to_name = {id_: data.get('name') for id_, data in graph.nodes(data=True)}
name_to_id = {data['name']: id_ for id_, data in graph.nodes(data=True) if 'name' in data}

# %%
#list all mammalian phenotypes
[id_to_name[x] for x in nx.ancestors(graph,'MP:0000001')]
# Out:
# ['thick epidermis stratum basale',
#  'increased alveolar lamellar body number',
#  'abnormal intestinal transit time',
#  'absent intercalated disks',
#  'abnormal pancreatic acinar cell zymogen granule morphology',
#  'decreased susceptibility to Orthomyxoviridae infection induced morbidity/mortality',
#  'decreased circulating interleukin-2 level',
#  'abnormal erythropoietin level',
#  'decreased pontine nuclei cell density',
#  'hemolytic anemia',
#  'increased vertebrae number',
#  'persistent ultimobranchial bodies',
#  'abnormal nail morphology',
#  'decreased cerebral cortex average cell area',
#  'increased erythrocyte magnesium ion content',
#  'abnormal thrombopoiesis',
#  'abnormal tela choroidea morphology',
#  'abnormal b-wave implicit time',
#  'increased tail rattling',
#  'abnormal infrapatellar fat pad morphology',
#  'abnormal seminal vesicle morphology',
#  'abnormal pulmonary alveolar parenchyma morphology',
#  'small vomeronasal organ',
#  'abnormal heart and great artery attachment',
#  'thymus medulla hypoplasia',
#  'abnormal olivary pretectal nucleus morphology',
#  'increased sperm motility',
#  'flat head',
#  'abnormal catechol O-methyltransferase activity',
#  'short kidney papilla',
#  'abnormal single cell response intensity',
#  'abnormal type IV hypersensitivity reaction',
#  'abnormal subarcuate fossa morphology',
#  'abnormal adipose tissue distribution',
#  'abnormal bone strength',
#  'absent vertebral pedicles',
#  'increased uterus carcinoma incidence',
#  'detached tectorial membrane',
#  'abnormal efferent lymphatic vessel morphology',
#  'abnormal middle ear development',
#  'abnormal superior colliculus average cell area',
#  'abnormal circulating interleukin-6 level',
#  'decreased susceptibility to parasitic infection induced morbidity/mortality',
#  'increased urine bicarbonate level',
#  'blood vessel degeneration',
#  'abnormal luminal closure',
#  'ureteropelvic junction obstruction',
#  'single Mullerian duct',
#  'vitreous body deposition',
#  'abnormal enteric cholinergic neuron morphology',
#  'abnormal interleukin-23 secretion',
#  'abnormal response to infection',
#  'abnormal synovial joint cavity morphology',
#  'abnormal proline oxidase activity',
#  'abnormal dishabituation',
#  'increased liver cholesterol level',
#  'pectus excavatum',
#  'abnormal transverse acetabular ligament morphology',
#  'decreased substantia nigra average cell area',
#  'moribund',
#  'retina hyperplasia',
#  'absent sperm annulus',
#  'abnormal outer dense fiber morphology',
#  'abnormal renal/urinary system physiology',
#  'macrovesicular hepatic steatosis',
#  'abnormal basophil cell number',
#  'incus hypoplasia',
#  'increased N-acetylgalactosamine-4-sulfatase protein level',
#  'enlarged adrenal gland x-zone',
#  'absent external female genitalia',
#  'choking',
#  'abnormal molar crown morphology',
#  'decreased CD8-positive, alpha-beta memory T cell number',
#  'abnormal infundibular recess of third ventricle morphology',
#  'decreased circulating xanthine level',
#  'absent digestive secretion',
#  'abnormal ejaculation',
#  'decreased femur yield load',
#  'abnormal pontine nuclei cell number',
#  'audiogenic seizures',
#  'nasal gland degeneration',
#  'abnormal bronchoconstrictive response',
#  'abnormal single cell response threshold',
#  'abnormal eccrine sweat gland morphology',
#  'abnormal motor learning',
#  'abnormal hippocampus granule cell layer',
#  'early exit from telogen phase',
#  'increased corpus callosum cell number',
#  'abnormal melanotroph morphology',
#  'small tectum',
#  'absent primordial germ cells',
#  'abnormal clitoral bone morphology',
#  'vision/eye phenotype',
#  'abnormal ureter physiology',
#  'abnormal megakaryocyte morphology',
#  'argyrophilic inclusion bodies',
#  'abnormal cranial cartilage morphology',
#  'decreased leucine level',
#  'short basicranium',
#  'eye swellings',
#  'decreased pruritus',
#  'abnormal semicircular canal morphology',
#  'absent pancreatic duct',
#  'abnormal distal visceral endoderm morphology',
#  'ectopic parathyroid gland',
#  'abnormal glomerular capillary endothelium morphology',
#  'abnormal enterocyte differentiation',
#  'abnormal liver parenchyma morphology',
#  'increased blood catalase activity',
#  'abnormal nasopharynx morphology',
#  'abnormal kidney papilla morphology',
#  'ambiguous external genitalia',
#  'abnormal trabecular bone thickness',
#  'absent internal male genitalia',
#  'short zygomatic bone',
#  'abnormal heart septum morphology',
#  'abnormal intromission',
#  'decreased ventromedial hypothalamic nucleus cell density',
#  'absent amniotic folds',
#  'increased large intestine length',
#  'peritoneal inflammation',
#  'abnormal plasma cell differentiation',
#  'increased gamma-aminobutyric acid level',
#  'abnormal interstitial cell of Cajal morphology',
#  'impaired branching involved in trachea morphogenesis',
#  'abnormal circulating hyaluronic acid level',
#  'abnormal behavior',
#  'decreased susceptibility to Herpesvirales infection',
#  'decreased fat cell mitochondrial DNA content',
#  'abnormal kidney afferent arteriole morphology',
#  'abnormal primary somatosensory cortex morphology',
#  'abnormal thymus trabecula morphology',
#  'increased telomere length',
#  'abnormal circulating sulfate level',
#  'decreased mesenchymal cell proliferation involved in lung development',
#  'decreased circulating thyroid-stimulating hormone level',
#  'thin zona pellucida',
#  'decreased thyroid gland weight',
#  'muscular ventricular septal defect',
#  'abnormal Harderian gland porphyrin secretion',
#  'thin cortical plate',
#  'abnormal muscle glycogen level',
#  'increased plasma anion gap',
#  'abnormal liver lobule morphology',
#  'decreased response to brain injury',
#  'abnormal enteric neural crest cell migration',
#  "absent Meckel's cartilage",
#  'abnormal ciliary epithelium morphology',
#  'blind vagina',
#  'abnormal susceptibility to induced morbidity/mortality',
#  'abnormal pituitary gland weight',
#  'absent falciform ligament',
#  'cor triatriatum dextrum',
#  'abnormal Ammon gyrus morphology',
#  'abnormal dentin mineralization',
#  'supravalvar pulmonary trunk stenosis',
#  'increased cerebral cortex pyramidal cell number',
#  'hindlimb paresis',
#  'thorax closed contusion',
#  'abnormal gallbladder volume',
#  'abnormal superior colliculus cell number',
#  'abnormal exorbital lacrimal gland morphology',
#  'abnormal limb muscle morphology',
#  'increased cellular sensitivity to ionizing radiation',
#  'premature endochondral bone ossification',
#  'absent double-negative T cells',
#  'abnormal hypodermis morphology',
#  'absent nipple sheath',
#  'absent type II pneumocytes',
#  'abnormal selenium level',
#  'sebaceous gland atrophy',
#  'increased susceptibility to Togaviridae infection induced morbidity/mortality',
#  'fusion of middle ear ossicles',
#  'abnormal myeloid cell number',
#  'bowed radius',
#  'abnormal malleus neck morphology',
#  'abnormal rostral neuropore morphology',
#  'decreased podocyte motility',
#  'abnormal astrocyte size',
#  'abnormal dosage compensation, by inactivation of X chromosome',
#  'increased cingulate cortex cell density',
#  'abnormal dendritic spine number',
#  'absent epiglottis',
#  'pituitary gland peliosis',
#  'abnormal cellular hemoglobin content',
#  'decreased pancreatic acinar cell number',
#  'increased urine chloride ion level',
#  'abnormal granulosa cell apoptosis',
#  'increased body mass index',
#  'absent orbicularis oculi muscle',
#  'increased susceptibility to Adenoviridae infection induced morbidity/mortality',
#  'absent Reichert cartilage',
#  'abnormal pancreatic acinus morphology',
#  'abnormal scala tympani morphology',
#  'pulmonary alveolar edema',
#  'decreased palatal rugae number',
#  'abnormal auditory cortex tonotopy',
#  'decreased nitrite level',
#  'increased retina hemangioma incidence',
#  'abnormal grip strength',
#  'small cecum',
#  'abnormal interventricular septum thickness',
#  'absent cochlear hair bundle ankle links',
#  'increased heart ventricle size',
#  'abnormal carotid artery origin',
#  'abnormal synaptic dopamine release',
#  'conjunctival hyperemia',
#  'abnormal splenocyte physiology',
#  'decreased drinking frequency',
#  'delayed muscle development',
#  'absent zygomatic bone',
#  'small proamniotic cavity',
#  'absent kidney',
#  'impaired sperm capacitation',
#  'impaired contractility of intestinal smooth muscle',
#  'small third pharyngeal arch',
#  'abnormal inner hair cell synaptic ribbon morphology',
#  'abnormal male membranous urethra morphology',
#  'abnormal granulocyte number',
#  'abnormal palate development',
#  'decreased circulating adrenocorticotropin level',
#  'fused tarsal bones',
#  'increased defecation amount',
#  'increased cochlear VIII nucleus size',
#  'abnormal bronchus epithelium morphology',
#  'abnormal preimplantation embryo morphology',
#  'decreased circulating CCL3 level',
#  'increased neocortex volume',
#  'abnormal cerebral artery morphology',
#  'cardiac murmur',
#  'absent sebocyte',
#  'abnormal intestinal villus goblet cell morphology',
#  'squamous metaplasia of urethral gland',
#  'decreased cranium length',
#  'increased brain sulfoglycosphingolipid level',
#  'abnormal nail plate morphology',
#  'abnormal oviduct size',
#  'abnormal pancreas weight',
#  'absent mandibular angle',
#  'abnormal myocardial trabeculae morphology',
#  'abnormal presphenoid synchondrosis',
#  'decreased ceruloplasmin level',
#  'increased circulating noradrenaline level',
#  'hematoma',
#  'abnormal spleen red pulp morphology',
#  'absent fetal ductus arteriosus',
#  'increased total fat pad weight',
#  'decreased tyrosine aminotransferase level',
#  'abnormal cardiac outflow tract development',
#  'increased fat cell mitochondrial DNA content',
#  'abnormal ventricle endocardium morphology',
#  'absent masticatory muscles',
#  'decreased urine lipocalin 2 level',
#  'disorganized photoreceptor outer segment',
#  'abnormal limbic system morphology',
#  'abnormal respiratory tract brush cell morphology',
#  'abnormal hair guard neuron morphology',
#  'abnormal cardiac muscle regeneration',
#  'degeneration of organ of Corti supporting cells',
#  'increased body height',
#  'abnormal scalene muscle morphology',
#  'anucleate',
#  'decreased susceptibility to Retroviridae infection',
#  'long photoreceptor outer segment',
#  'abnormal hair follicle outer root sheath morphology',
#  'decreased myeloid dendritic cell number',
#  'abnormal brain weight',
#  'abnormal manchette assembly',
#  'decreased circulating anti-Mullerian hormone level',
#  'decreased middle ear goblet cell number',
#  'iris hyperplasia',
#  'increased platelet aggregation',
#  'increased tympanic ring size',
#  'absent parasellar internal carotid artery',
#  'increased B-2 B cell number',
#  'increased susceptibility to glomerulonephritis',
#  'absent interparietal bone',
#  'absent infundibular recess of third ventricle',
#  'abnormal transverse gyrus of Heschl morphology',
#  'retrogenia',
#  'absent chondrocytes',
#  'otocephaly',
#  'abnormal potassium level',
#  'abnormal tympanic cavity morphology',
#  'decreased nitric oxide synthase 1 level',
#  'abnormal female inguinal canal morphology',
#  'increased lipocalin 2 level',
#  'rhinorrhea',
#  'abnormal vagus ganglion morphology',
#  'decreased reticular tumor incidence',
#  'increased curvature of awl hairs',
#  'abnormal cerebellum fastigial nucleus average cell area',
#  'abnormal rhombomere 2 morphology',
#  'thick epidermis',
#  'polysyndactyly',
#  'abnormal thoracic aorta morphology',
#  'increased autoantibody level',
#  'abnormal aqueous vein morphology',
#  'abnormal canthus morphology',
#  'decreased circulating hydroxyproline level',
#  'enhanced discrimination learning',
#  'abnormal symmetric synapse morphology',
#  'increased bone mineral density',
#  'abnormal L3 dorsal root ganglion morphology',
#  'abnormal radius morphology',
#  'abnormal vascular endothelial cell development',
#  'enhanced female fertility',
#  'abnormal stylohyoid ligament morphology',
#  'abnormal hippocampal commissure morphology',
#  'increased brain external capsule size',
#  'absent cerebellum vermis',
#  'abnormal fetal derived definitive erythrocyte physiology',
#  'enhanced pulmonary alveolar fluid clearance',
#  'embryonic-extraembryonic boundary constriction',
#  'abnormal tibiofemoral joint morphology',
#  'decreased femor compact bone volume',
#  'skeleton phenotype',
#  'small gonial bone',
#  'disorganized sperm mitochondrial sheath',
#  'absent posterior semicircular canal',
#  'abnormal hepatic vein connection',
#  'abnormal dental pulp morphology',
#  'keratoconjunctivitis sicca',
#  'abnormal cellular extravasation',
#  'proctitis',
#  'decreased lipogenesis',
#  'encephalopathy',
#  'abnormal seminiferous tubule morphology',
#  'abnormal kindling response',
#  'abnormal type IV spiral ligament fibrocytes',
#  'enlarged lumbar vertebrae',
#  'decreased activated sperm motility',
#  'decreased dorsal striatum average cell area',
#  'thin vagus nerve',
#  'increased number of Howell-Jolly bodies',
#  'decreased susceptibility to weight gain',
#  'decreased gamma-delta intraepithelial T cell number',
#  'broad nasal bone',
#  'pyloric sphincter hypertrophy',
#  'increased pancreas apoptosis',
#  'abnormal neural crest morphology',
#  'increased circulating fibrinogen level',
#  'abnormal oligodendrocyte morphology',
#  'small neurocranium',
#  'increased cystathionine level',
#  'abnormal hair follicle melanocyte morphology',
#  'abnormal conjunctival sac morphology',
#  'increased drinking frequency',
#  'calcified aortic valve cusp',
#  'truncated notochord',
#  'absent right lung accessory lobe',
#  'decreased right ventricle systolic pressure',
#  'excessive ear growth',
#  'abnormal ophthalmic nerve morphology',
#  'decreased CNS synapse formation',
#  'cornea scarring',
#  'decreased submucosal gland secretion',
#  'abnormal heart elastic tissue morphology',
#  'enhanced behavioral response to anesthetic',
#  'abnormal areola morphology',
#  'small submandibular ganglion',
#  'abnormal nephron morphology',
#  'abnormal mammary gland embryonic development',
#  'choroid coloboma',
#  'abnormal inner hair cell kinocilium morphology',
#  'increased brain magnesium level',
#  'abnormal long bone epiphysis morphology',
#  'decreased thiopurine S-methyltransferase activity',
#  'abnormal fornicate gyrus morphology',
#  'gastrointestinal arteriovenous malformation',
#  'increased solitary pulmonary neuroendocrine cell number',
#  'abnormal cerebrospinal fluid physiology',
#  'decreased prostate gland ventral lobe weight',
#  'abnormal pancreatic beta cell morphology',
#  'abnormal early pro-B cell',
#  'absent acrosome',
#  'unilateral cleft palate',
#  'absent sclerotome',
#  'abnormal carbohydrate metabolism',
#  'cataract',
#  'abnormal melanoblast apoptosis',
#  'increased brain glycogen level',
#  'increased glucose-6-phosphate dehydrogenase activity',
#  'decreased circulating valine level',
#  'absent bronchioalveolar stem cells',
#  'increased hypodermis neovascularization',
#  'increased procollagen-proline 4-dioxygenase activity',
#  'narrow face',
#  'abnormal blood viscosity',
#  'absent lymphatic vessels',
#  'hunched posture',
#  'abnormal Langerhans cell morphology',
#  'abnormal fetal cardiomyocyte morphology',
#  'abnormal nasal cartilage morphology',
#  'abnormal sphenooccipital synchondrosis',
#  'embryonic lethality between implantation and placentation, incomplete penetrance',
#  'abnormal circulating interferon-alpha level',
#  'abnormal miscarriage rate',
#  'abnormal nipple sheath morphology',
#  'abnormal exocrine pancreas physiology',
#  'abnormal proximal-distal axis patterning',
#  'impaired pancreas regeneration',
#  'abnormal pulmonary endothelial cell surface',
#  'abnormal aqueous drainage system morphology',
#  'enlarged pericardium',
#  'impaired granulosa cell differentiation',
#  'increased rhabdomyoma incidence',
#  'increased circulating creatine kinase level',
#  'sagittal suture sclerosis',
#  'abnormal interleukin level',
#  'abnormal operant conditioning behavior',
#  'decreased spleen weight',
#  'abnormal respiratory system physiology',
#  'abnormal cochlear nerve fiber response',
#  'abnormal hind foot hair pigmentation',
#  'liver degeneration',
#  'abnormal intestinal epithelium morphology',
#  'abnormal tarsal bone morphology',
#  'absent jugular lymph sacs',
#  'abnormal pituitary gland physiology',
#  'rectal hemorrhage',
#  'abnormal pulmonary valve development',
#  'increased spinal cord apoptosis',
#  'tooth abscess',
#  'abnormal prostaglandin level',
#  'absent scapula',
#  'abnormal intestinal iron level',
#  'abnormal endocardium development',
#  'abnormal ether lipid level',
#  'abnormal neutrophil morphology',
#  'slow extinction of fear memory',
#  'increased prostate intraepithelial neoplasia incidence',
#  'hair follicle inner root sheath hyperplasia',
#  'abnormal granulocyte morphology',
#  'prolonged estrus',
#  'absent iris stroma',
#  'embryonic lethality prior to organogenesis, incomplete penetrance',
#  'decreased circulating mineralocorticoid level',
#  'decreased sperm mitochondrial size',
#  'abnormal circulating ghrelin level',
#  'abnormal CD11b-high dendritic cell number',
#  'abnormal small intestinal crypt cell physiology',
#  'abnormal common carotid artery topology',
#  'microdontia',
#  'proteinosis',
#  'decreased hippocampus cell number',
#  'increased arginine level',
#  'decreased vertebrae number',
#  'increased glucagon secretion',
#  'abnormal iris transillumination',
#  'granulomatous inflammation',
#  'impaired lectin complement pathway',
#  'absent inferior vena cava',
#  'embryonic lethality between implantation and somite formation',
#  'abnormal osteocyte lacunocanalicular system morphology',
#  'anal soreness',
#  'decreased alpha-beta T cell number',
#  'abnormal spatial working memory',
#  'abnormal occipital lobe morphology',
#  'abnormal head size',
#  'abnormal brain size',
#  'oocyte degeneration',
#  'abnormal keratinocyte apoptosis',
#  'increased superior colliculus cell number',
#  'increased response to stress-induced hyperthermia',
#  'increased circulating glucose level',
#  'heterotaxia',
#  'enlarged inferior vena cava valve',
#  'abnormal granulosa cell proliferation',
#  'abnormal cerebellum vermis lobule VIII morphology',
#  'increased beta-galactosidase level',
#  'abnormal Hertwig epithelial root sheath morphology',
#  'abnormal ovary tissue architecture',
#  'small orbits',
#  'calcified pulmonary alveolus',
#  'abnormal T cell receptor V(D)J recombination',
#  'increased prolactin level',
#  'decreased epididymal fat pad weight',
#  'abnormal esophageal smooth muscle morphology',
#  'thick tricuspid valve',
#  'increased glucokinase activity',
#  'fused bronchial cartilage rings',
#  'abnormal cellular ATP level',
#  'abnormal pollex morphology',
#  'increased bone mineral density of femur',
#  'absent suckling reflex',
#  'abnormal mesonephric mesenchyme morphology',
#  'abnormal blood cell physiology',
#  'increased mammary gland number',
#  'abnormal olfactory epithelium physiology',
#  'abnormal brain zinc level',
#  'decreased thyroxine level',
#  'enlarged maxillary prominence',
#  'increased urine beta2-microglobulin level',
#  'increased radius size',
#  'abnormal eye muscle morphology',
#  'abnormal palatal length',
#  'decreased cardiac muscle glycogen level',
#  'decreased femur size',
#  'positive geotaxis',
#  'small pupil',
#  'thoracic aorta aneurysm',
#  'abnormal Sertoli cell barrier function',
#  'absent circulating noradrenaline',
#  'abnormal submandibular gland morphology',
#  'increased circulating histamine level',
#  'abnormal mastication',
#  'decreased hemoglobin concentration distribution width',
#  'abnormal respiratory epithelial chloride transmembrane transport',
#  'abnormal hair follicle infundibulum morphology',
#  'abnormal cystic duct morphology',
#  'increased heart left ventricle septal wall thickness',
#  'increased erythrocyte clearance',
#  'limb open laceration',
#  'abnormal neural crest cell apoptosis',
#  'stomach hemorrhage',
#  'decreased otic epithelial cell proliferation',
#  'decreased splenocyte number',
#  'abnormal outer hair cell stereocilia length',
#  'absent choroid plexus',
#  'abnormal skeletal muscle satellite cell proliferation',
#  'abnormal glucagon secretion',
#  'abnormal duodenal goblet cell morphology',
#  'decreased incisor number',
#  'increased plasma cell number',
#  'increased kidney catalase level',
#  'anal fistula',
#  'abnormal node of Ranvier morphology',
#  'abnormal posterior longitudinal ligament morphology',
#  'abnormal circulating triiodothyronine level',
#  'abnormal behavioral response to light',
#  'abnormal nucleus pulposus morphology',
#  'abnormal pancreatic epsilon cell differentiation',
#  'bifid ureter',
#  'abnormal dendritic epidermal T cell morphology',
#  'ethylmalonic aciduria',
#  'increased circulating interleukin-8 level',
#  'increased forebrain size',
#  'optic nerve swelling',
#  'decreased circulating glutamate dehydrogenase level',
#  'abnormal resting posture',
#  'absent temporomandibular joint disk',
#  'delayed bone mineralization',
#  'absent trabecular meshwork',
#  'enlarged ileum',
#  'abnormal common peroneal nerve morphology',
#  'ovary hyperplasia',
#  'abnormal circadian regulation of heart rate',
#  'abnormal endolymphatic sac topology',
#  'abnormal enteric neuron morphology',
#  'abnormal hyoglossus muscle morphology',
#  'increased nitrate level',
#  'decreased germ cell number',
#  'calcified aortic arch',
#  'absent philtrum',
#  'small caudate nucleus',
#  'abnormal portal triad morphology',
#  'absent B cells',
#  'abnormal syncytiotrophoblast morphology',
#  'abnormal atrioventricular septum morphology',
#  'total anomalous pulmonary venous connection, infracardiac',
#  'short nasal septum',
#  'cyanosis',
#  'celiac artery compression',
#  'descending aorta dilation',
#  'decreased bone mineral density of lumbar vertebrae',
#  'enlarged spinous cells',
#  'abnormal vasodilation',
#  'intestinal/bowel diverticulum',
#  'abnormal renal tubule morphology',
#  'impaired natural killer cell mediated cytotoxicity',
#  'abnormal male meiosis',
#  'abnormal compensatory feeding amount',
#  'abnormal cerebellar lobule formation',
#  'increased threonine level',
#  'choroid atrophy',
#  'abnormal tumor necrosis factor (ligand) superfamily member 11 level',
#  'absent hair club',
#  'abnormal molar morphology',
#  'abnormal sperm axoneme morphology',
#  'absent barrels in primary somatosensory cortex',
#  'absent retina',
#  'abnormal Langerhans cell antigen presentation',
#  'abnormal cell chemotaxis',
#  'increased pancreatic beta cell mass',
#  'encephalomeningocele',
#  'increased melanoma incidence',
#  'abnormal chromosomal synapsis',
#  'pancreas lipomatosis',
#  'stereotypic behavior',
#  'abnormal superior cerebellar artery morphology',
#  'streak gonad',
#  'increased organ/body region tumor incidence',
#  'gonial bone hyperplasia',
#  'abnormal paraflocculus morphology',
#  'abdomen open avulsion',
#  'increased dopaminergic neuron number',
#  'anuria',
#  'skin fibrosis',
#  'abnormal ureteric bud morphology',
#  'palate inflammation',
#  'caudal hemivertebra',
#  'absent tympanic cavity',
#  'abnormal brain ependyma motile cilium physiology',
#  'abnormal pancreatic duct epithelial chloride transmembrane transport',
#  'abnormal chemically-elicited antinociception',
#  'increased cellular sensitivity to thiophosphamide',
#  'small lung',
#  'abnormal glycerol level',
#  'urethrovaginal fistula',
#  'increased gastrointestinal tumor incidence',
#  'abnormal diaphragm development',
#  'increased liver secretion',
#  'abnormal allantois morphology',
#  'polyuria',
#  'split sternum',
#  'abnormal skin physiology',
#  'abnormal platelet calcium level',
#  'decreased circulating phenylalanine level',
#  'absent maxillary sinus',
#  'abnormal perineural vascular plexus morphology',
#  'abnormal retrotrapezoid nucleus morphology',
#  'abnormal pigmentation pattern',
#  'absent hindlimb buds',
#  'absent pancreatic acinar cells',
#  'increased volumetric bone mineral density',
#  'abnormal cell motility',
#  'abnormal cauda epididymis morphology',
#  'abnormal complement C5 level',
#  'abnormal circadian behavior period',
#  'abnormal vitelline artery morphology',
#  'abnormal palatal shelf elevation',
#  'abnormal pituitary hormone level',
#  'abnormal third pharyngeal pouch morphology',
#  'decreased circulating magnesium level',
#  'abnormal cementoenamel junction morphology',
#  'thick epidermis suprabasal layer',
#  'abnormal aorta tunica media morphology',
#  'stomach inflammation',
#  'round forehead',
#  'delayed inner ear development',
#  'decreased circulating transferrin level',
#  'abnormal uterine cervix morphology',
#  'abnormal lithium metabolism',
#  'decreased circulating phosphate level',
#  'absent thymus corticomedullary boundary',
#  'increased myeloid cell number in bone marrow',
#  'increased lymphocyte chemotaxis',
#  'abnormal CD4-negative NK T cell number',
#  'abnormal thymus physiology',
#  'abnormal lung position or orientation',
#  'myelencephalic blebs',
#  'stomach non-glandular epithelium hyperkeratosis',
#  'absent nasopharynx',
#  'periinsulitis',
#  'abnormal circulating factor VIII level',
#  'abnormal kidney interlobar artery morphology',
#  'increased kidney weight',
#  'dilated dorsal aorta',
#  'abnormal respiratory system development',
#  'paternal imprinting',
#  'increased skeletal muscle cell apoptosis',
#  'pharyngeal arch artery hypoplasia',
#  'decreased interleukin-1 beta secretion',
#  'paternal effect',
#  'increased tubuloglomerular feedback response',
#  'abnormal cerebellum emboliform nucleus morphology',
#  'abnormal hippocampus granule cell morphology',
#  'short metatarsal bones',
#  'embryonic lethality between somite formation and embryo turning',
#  'decreased proline oxidase activity',
#  'impaired learning',
#  'abnormal lens vesicle development',
#  'abnormal baroreceptor morphology',
#  'decreased inflammatory response',
#  'decreased vascular permeability',
#  'abnormal gland development',
#  'decreased erythrocyte sodium:hydrogen antiporter activity',
#  'maxillary prominence hypoplasia',
#  'abnormal dental arch morphology',
#  'increased cardiomyocyte apoptosis',
#  'taurinuria',
#  'impaired exercise endurance',
#  'short facial bone',
#  'abnormal eyelid cilium number',
#  'nasal septum hypoplasia',
#  'hypoxemia',
#  'embryo phenotype',
#  'abnormal inguinal mammary gland morphology',
#  'abnormal tumor incidence',
#  'abnormal nasal capsule morphology',
#  'abnormal fetal cardiomyocyte apoptosis',
#  'increased hindlimb autopod size',
#  'absent metanephric mesenchyme',
#  'abnormal sternoclavicular joint morphology',
#  'increased cerebral cortex average cell area',
#  'decreased tongue size',
#  'kidney medulla cyst',
#  'increased luteinizing hormone level',
#  'abnormal posterior eye segment morphology',
#  'abnormal jeujunal goblet cell morphology',
#  'toxic megacolon',
#  'abnormal myenteric nerve plexus morphology',
#  'ureteropelvic junction stenosis',
#  'abnormal embryo size',
#  'seminal vesicle hypoplasia',
#  'perianal ulcer',
#  'impaired behavioral response to addictive substance',
#  'abnormal stomach cardiac region morphology',
#  'abnormal lymphatic vessel endothelial cell morphology',
#  'abnormal hippocampus development',
#  'abnormal middle ear ossicle morphology',
#  'abnormal labia majora morphology',
#  'increased thyroid tumor incidence',
#  'abnormal sinus arrhythmia',
#  'absent anterior primitive streak',
#  'abnormal crista terminalis morphology',
#  'abnormal pineal gland melatonin secretion',
#  'decreased b-wave amplitude',
#  'dysosmia',
#  'increased circulating testosterone level',
#  'delayed embryo implantation',
#  'absent spleen marginal zone',
#  'abnormal cell death',
#  'abnormal hepatic portal vein morphology',
#  'reddish skin',
#  'absent snout',
#  'abnormal Wolffian duct topology',
#  'abnormal heart left ventricle pressure',
#  'abnormal acute locomotor response to cocaine',
#  'bone fibrous dysplasia',
#  'absent sexual maturation',
#  'increased fetal cardiomyocyte number',
#  'decreased somatotroph secretory granule number',
#  'abnormal acromioclavicular joint morphology',
#  'impaired social recognition',
#  'increased feces bile salt level',
#  'hydroxyprolinuria',
#  'increased acute inflammation',
#  'increased total lung capacity',
#  'abnormal channel response threshold',
#  'abnormal circulating interleukin-2 level',
#  'decreased papilloma incidence',
#  'abnormal femur neck morphology',
#  'decreased uterine fat pad weight',
#  'thymus fibrosis',
#  'decreased platelet calcium level',
#  'abnormal corpus callosum total cell area',
#  'abnormal cell morphology',
#  'abnormal visceral yolk sac morphology',
#  'decreased lean body mass',
#  'hemivertebra',
#  'decreased enterocyte apoptosis',
#  'abnormal thalamus cell number',
#  'delayed rostral neuropore closure',
#  'abnormal ossification involved in bone remodeling',
#  'increased femur maximal load',
#  'increased circulating interleukin-10 level',
#  'increased neuroblastoma incidence',
#  'left-sided isomerism',
#  'arytenoid and cricoid cartilage fusion',
#  'polydactyly',
#  'abnormal spleen marginal zone macrophage morphology',
#  'increased papillary muscle size',
#  'increased IgA level',
#  'abnormal periodontal ligament morphology',
#  'absent utricle',
#  'decreased skeletal muscle cell apoptosis',
#  'abnormal haloperidol metabolism',
#  'abnormal pancreatic duct morphology',
#  'photoreceptor inner segment degeneration',
#  'abnormal maternal body weight gain',
#  'absent brain ependyma motile cilia',
#  'abnormal circulating LDL cholesterol level',
#  'impaired branching involved in alveolar duct morphogenesis',
#  'increased circulating estrogen level',
#  'maxillary retrognathia',
#  'increased carbon dioxide production',
#  'increased coumarin hydroxylase activity',
#  'gastric metaplasia',
#  'decreased QRS amplitude',
#  'pyelonephritis',
#  'hematuria',
#  'muscle weakness',
#  'abnormal neocortex size',
#  'abnormal theca externa morphology',
#  'decreased cerebral cortex total cell area',
#  'absent granulocyte monocyte progenitor cells',
#  'enlarged cranium',
#  'increased brain apoptosis',
#  'abnormal mineral homeostasis',
#  'gastroesophageal reflux',
#  'abnormal vena cava morphology',
#  'sebaceous gland hypoplasia',
#  'abnormal intestine regeneration',
#  'thick cerebellar granule layer',
#  'abnormal mammary gland duct morphology',
#  'abnormal thyrotroph morphology',
#  'small brain ventricles',
#  'absence of NMDA-mediated synaptic currents',
#  'thick lung-associated mesenchyme',
#  'abnormal vitelline vasculature morphology',
#  'decreased keratohyalin granule size',
#  'increased mitochondrial number',
#  'impaired febrile response',
#  'abnormal sensitization',
#  'progressive muscle weakness',
#  'abnormal skeletal muscle fiber type ratio',
#  'abnormal circulating vitamin C level',
#  'increased birth weight',
#  'abnormal lymph node T cell domain morphology',
#  'abnormal gum epithelium morphology',
#  'head or neck wound',
#  'ovary inflammation',
#  'decreased heart left ventricle posterior wall thickness',
#  'cerebellum vermis hypoplasia',
#  'increased mitochondrial size',
#  'abnormal hepatic portal vein formation',
#  'abnormal fetal liver hematopoietic progenitor cell morphology',
#  'greasy coat',
#  'head mesenchyme necrosis',
#  'abnormal urine uric acid level',
#  'abnormal first pharyngeal pouch morphology',
#  'abnormal basioccipital bone morphology',
#  'dilated uterine horn',
#  'increased bleeding time',
#  'absent vestibular hair cells',
#  'increased anandamide level',
#  'increased susceptibility to induction of seizure by inducing agent',
#  'abnormal circumvallate papillae morphology',
#  'abnormal somite size',
#  'abnormal stride length',
#  'increased muscle fatigability',
#  'enlarged interparietal bone',
#  'abnormal subscapular fat pad morphology',
#  'abnormal skeletal muscle fiber morphology',
#  'increased vitamin D level',
#  'increased circulating amylase level',
#  'decreased frequency of paradoxical sleep',
#  'spasticity',
#  'trigonocephaly',
#  'abnormal cerebellum vermis lobule VIIb morphology',
#  'increased metastatic potential',
#  'areflexia',
#  'increased susceptibility to infection induced morbidity/mortality',
#  'absent canalicular internal carotid artery segment',
#  'decreased cochlea coiling',
#  'abnormal cardiac epithelial to mesenchymal transition',
#  'thick zygomatic arch',
#  'atrioventricular valve hyperplasia',
#  'decreased pancreas iron level',
#  'abnormal bulbar conjunctiva morphology',
#  'Meibomian gland hypoplasia',
#  'enlarged dorsal root ganglion',
#  'increased superior colliculus average cell area',
#  'increased pancreatic intraepithelial neoplasia incidence',
#  'abnormal embryonic erythrocyte morphology',
#  'detached periodontal ligament',
#  'Deiters cell degeneration',
#  'abnormal circulating calcium level',
#  'abnormal pancreatic endocrine progenitor cell physiology',
#  'abnormal cornea stroma development',
#  'small clitoris',
#  'abnormal agouti pigmentation',
#  'atrial septal aneurysm',
#  'abnormal hypoglossal cord morphology',
#  'decreased mammary gland number',
#  'short vertebral column',
#  'abnormal fetal ductus arteriosus morphology',
#  'abnormal behavioral response to methylenedioxymethamphetamine',
#  'increased circulating vitamin C level',
#  'increased cochlea length',
#  'abnormal cochlear endolymph ionic homeostasis',
#  'binucleate',
#  'abnormal dorsal interneuron 5 morphology',
#  'ventricular cardiomyopathy',
#  'increased gastrointestinal stromal tumor incidence',
#  'decreased circulating homocysteine level',
#  'abnormal inner ear vestibule morphology',
#  'abnormal endolymph physiology',
#  'abnormal conjunctiva goblet cell number',
#  "decreased Reichert's membrane thickness",
#  'decreased circulating interleukin-1 beta level',
#  'increased macrophage cytokine production',
#  'abnormal dentin morphology',
#  'fused pharyngeal arches',
#  'abnormal bronchial provocation',
#  'decreased hydroxyproline level',
#  'postnatal lethality, incomplete penetrance',
#  'increased cerebral cortex cell number',
#  'abnormal urine protein level',
#  'hairless tail',
#  'sclera thinning',
#  'philtrum hypoplasia',
#  'abnormal nasal pit morphology',
#  'increased gallbladder volume',
#  'abnormal anterior cranial fossa',
#  'abnormal oligodendrocyte apoptosis',
#  'increased hypothalamus hypoxanthine-guanine phosphoribosyltransferase level',
#  'abnormal kidney glycogen level',
#  'abnormal circulating gastrin level',
#  'abnormal cochlear sensory epithelium morphology',
#  'decreased pulmonary ventilation',
#  'shiny fur',
#  'ageusia',
#  'small ureteric bud',
#  'abnormal tympanic ring morphology',
#  'abnormal tooth physiology',
#  'abnormal cementoblast morphology',
#  'abnormal erythrocyte osmotic lysis',
#  'thick retina inner nuclear layer',
#  'increased anti-single stranded DNA antibody level',
#  'abnormal tail ring morphology',
#  'impaired behavioral response to cocaine',
#  'decreased hippocampal fimbria average cell area',
#  'abnormal mammary placode morphology',
#  'abnormal tooth hard tissue morphology',
#  'long outer hair cell stereocilia',
#  'increased bone mineral density of sacral vertebrae',
#  'increased thyroxine level',
#  'increased embryonic epiblast cell apoptosis',
#  'abnormal circadian behavior phase',
#  'decreased optic chiasm average cell area',
#  'abnormal cerebellum external granule cell layer morphology',
#  'abnormal embryonic erythropoiesis',
#  'glossopharyngeal nerve hypoplasia',
#  'abnormal cerebellum vermis lobule VIIa morphology',
#  'increased circulating fibronectin level',
#  'abnormal embryonic neuroepithelium primary cilium morphology',
#  'abnormal epididymis epithelium morphology',
#  'lymphatic vessel hypoplasia',
#  'abnormal KLRG1-positive CD4-positive, CD25-positive, alpha-beta regulatory T cell number',
#  'decreased B-1 B cell number',
#  'stomach smooth muscle circular layer hypertrophy',
#  'abnormal glucose tolerance',
#  'white pupil',
#  'abnormal dermal layer morphology',
#  'impaired pupillary reflex',
#  'absent long-term depression',
#  'stomach mucosa hyperplasia',
#  'greasy head/neck',
#  'abnormal circulating fibronectin level',
#  'excessive tearing',
#  'abnormal thalamus cell density',
#  'decreased dopaminergic neuron number',
#  'lactation failure',
#  'acute pancreas inflammation',
#  'hemitruncus',
#  'abnormal amyloid beta protein level',
#  'abnormal blastocoele morphology',
#  'abnormal direction of heart looping',
#  'abnormal branching involved in seminal vesicle morphogenesis',
#  'decreased facial hemangioma incidence',
#  'abnormal trigeminal V mesencephalic nucleus morphology',
#  'increased areal bone mineral density',
#  'abnormal erythrocyte sodium:potassium-exchanging ATPase activity',
#  'abnormal pelvic girdle bone morphology',
#  'abdomen open puncture',
#  'decreased angiogenesis',
#  'increased guanylate cyclase activating protein-2 level',
#  'decreased cerebral infarct size',
#  'gastric gland degeneration',
#  'abnormal femur morphology',
#  'thin epidermis stratum basale',
#  'small horns',
#  'increased internal diameter of femur',
#  'decreased brain external capsule size',
#  'abnormal cerebellum fastigial nucleus cell density',
#  'enhanced skeletal muscle regeneration',
#  'abnormal Ly6C low monocyte number',
#  'decreased coumarin hydroxylase activity',
#  'decreased airway responsiveness',
#  'abnormal syndesmosis morphology',
#  'glomerulonephritis',
#  'increased hippocampal fimbria total cell area',
#  'abnormal acellular cementum morphology',
#  'absent CD4-positive, alpha-beta T cells',
#  'absent pancreatic beta cells',
#  'increased prepulse inhibition',
#  'increased brain zinc level',
#  'decreased soleus weight',
#  'laryngeal cleft',
#  'abnormal brain arachnoid mater morphology',
#  'abnormal hindlimb bud morphology',
#  'abnormal MHC II cell surface expression on macrophages',
#  'increased circulating VLDL cholesterol level',
#  'absent megakaryocyte-erythroid progenitor cells',
#  'erythroblastosis',
#  'absent tricuspid valve cusps',
#  'decreased muscle glycogen level',
#  'abnormal conjunctival vasculature morphology',
#  'abnormal circulating troponin level',
#  'increased endoneurial fluid pressure',
#  'abnormal eye morphology',
#  'abnormal synaptic vesicle exocytosis',
#  'abnormal peritubular capillary morphology',
#  'increased megakaryocyte progenitor cell number',
#  'abnormal epicardium morphology',
#  'increased renal vascular resistance',
#  'abnormal uterine NK cell morphology',
#  ...]

# %%
par=[id_to_name[x] for x in graph.predecessors('MP:0000001')]

# %% [markdown]
# # validate whole network in PARENT traits

# %%
#return list set of traits in  ontology including parent- reported by name
def return_descendents_name(graph,id_to_name, term):
    l=list(sorted(id_to_name[subterm] for subterm in nx.ancestors(graph, term))) #descendents get subterms- not sure why but I tested it and OBONET says so as well
    l.append(id_to_name[term])
    return list(set(l))

# %%
#return list set of traits in  ontology including parent- reported by name
def return_ancestors_name(graph,id_to_name, term):
    print('getting ancestors for '+term+' : '+id_to_name[term])
    l=list((id_to_name[supterm] for supterm in nx.descendants(graph, term))) #descendents get superterms- not sure why
    #l.append(id_to_name[term])
    return list(set(l))

# %%
coloc_dict_cat={}
for k in coloc_dict.keys():
    coloc_dict_cat[k]=set(coloc_dict[k]).intersection(list(cat['GENE'].dropna()))

# %%
p='behavior/neurological phenotype'

# %%
    children=return_descendents_name(graph,id_to_name, name_to_id[p])
    t=(cat[cat['subject_id'].isin([name_to_id[x] for x in children])])

# %%
set(t['TRAIT'])
# Out:
# {'anorexia nervosa: anorexia nervosa (PMID: 21079607)',
#  'anorexia nervosa: anorexia nervosa (PMID: 23568457)',
#  'anorexia nervosa: anorexia nervosa (PMID: 24514567)',
#  'anorexia nervosa: anorexia nervosa (PMID: 28494655)',
#  'anorexia nervosa: anorexia nervosa (PMID: 29155802)',
#  'anorexia nervosa: anorexia nervosa (PMID: 31308545)',
#  'anxiety disorder, environmental factor: anxiety x environmental factor score interaction (PMID: 35026594)',
#  'anxiety disorder, panic disorder: anxiety disorders (PMID: 31906708)',
#  'anxiety disorder, response to selective serotonin reuptake inhibitor: ssri response to somatic anxiety syndromal factor measured by ham-d-21 in major depressive disorder (PMID: 36658263)',
#  'anxiety disorder, stress-related disorder: anxiety and stress-related disorders (PMID: 31116379)',
#  'anxiety disorder, stress-related disorder: anxiety and stress-related disorders (excluding adjustment disorder) (PMID: 31116379)',
#  'anxiety disorder, stress-related disorder: anxiety and stress-related disorders (excluding co-morbid schizophrenia) (PMID: 31116379)',
#  'anxiety disorder, stress-related disorder: anxiety and stress-related disorders (including obsessive-compulsive disorder) (PMID: 31116379)',
#  'anxiety disorder, stress-related disorder: anxiety and stress-related disorders (psychiatric co-morbidity covariate model) (PMID: 31116379)',
#  'anxiety disorder, stress-related disorder: anxiety and stress-related disorders (psychiatric co-morbidity weighting design) (PMID: 31116379)',
#  'anxiety disorder: anxiety disorder (PMID: 25390645)',
#  'anxiety disorder: anxiety disorder (PMID: 26754954)',
#  'anxiety disorder: anxiety disorders (PMID: 31116379)',
#  'anxiety disorder: lifetime anxiety disorder (PMID: 31748690)',
#  'anxiety, stress-related disorder: anxiety and stress-related disorders (PMID: 34634379)',
#  'asthma, anxiety disorder: asthma and anxiety disorder (PMID: 31619474)',
#  "bell's palsy: bell's palsy (PMID: 33602968)",
#  "bell's palsy: bell's palsy (PMID: 34594039)",
#  'callous-unemotional behaviour: callous-unemotional behaviour (PMID: 23874384)',
#  'chronic fatigue syndrome: myalgic encephalomyelitis / chronic fatigue syndrome (PMID: 35318112)',
#  'decreased walking ability: walking difficulty in charcot-marie-tooth disease 1a (PMID: 30958311)',
#  'diastolic blood pressure, social deprivation: diastolic blood pressure x low social support interaction (2df test) (PMID: 34734193)',
#  'eating disorder, bipolar disorder: bipolar disorder and eating disorder (PMID: 26433762)',
#  'eating disorder: eating disorder in bipolar disorder (PMID: 26433762)',
#  'eating disorder: eating disorders (PMID: 23568457)',
#  'eating disorder: eating disorders (purging via substances) (PMID: 23568457)',
#  'epilepsy, response to xenobiotic stimulus: epilepsy (remission after treatment) (PMID: 23962720)',
#  'epilepsy: epilepsy (PMID: 22116939)',
#  'epilepsy: epilepsy (PMID: 25087078)',
#  'epilepsy: epilepsy (PMID: 30531953)',
#  'epilepsy: epilepsy (PMID: 33913524)',
#  'epilepsy: epilepsy (PMID: 34456681)',
#  'epilepsy: epilepsy (PMID: 34594039)',
#  'epilepsy: epilepsy (PMID: 37653029)',
#  'epilepsy: generalized epilepsy (PMID: 22949513)',
#  'epilepsy: genetic generalized epilepsy or focal epilepsy (pleiotropy) (PMID: 37653029)',
#  'generalised epilepsy: epilepsy (PMID: 25087078)',
#  'generalised epilepsy: generalized epilepsy (PMID: 30531953)',
#  'generalised epilepsy: generalized epilepsy (PMID: 34573423)',
#  'mean arterial pressure, social deprivation: mean arterial pressure x low social support interaction (1df test) (PMID: 34734193)',
#  'mean arterial pressure, social deprivation: mean arterial pressure x low social support interaction (2df test) (PMID: 34734193)',
#  'mental or behavioural disorder: eating disorders (PMID: 22911880)',
#  'movement disorder: tardive dyskinesia (PMID: 21826085)',
#  'partial epilepsy: epilepsy (PMID: 25087078)',
#  'pulse pressure measurement, social deprivation: pulse pressure x low social support interaction (1df test) (PMID: 34734193)',
#  'pulse pressure measurement, social deprivation: pulse pressure x low social support interaction (2df test) (PMID: 34734193)',
#  'rem sleep behavior disorder: rem sleep behavior disorder (probable or isolated) (PMID: 36470867)',
#  'same-sex sexual behavior: same-sex sexual behaviour (PMID: 31467194)',
#  'short sleep: nap duration in broad depression (PMID: 36463630)',
#  'short sleep: nap duration in severe depression (PMID: 36463630)',
#  'social communication impairment: social communication problems (PMID: 24047820)',
#  'social communication impairment: social communication problems (PMID: 24564958)',
#  'social deprivation, covid-19: covid-19 (severe vs population) x multiple deprivation index interaction (PMID: 35096005)',
#  'social deprivation, covid-19: covid-19 (severe vs population) x multiple deprivation index interaction (joint test) (PMID: 35096005)',
#  'social deprivation, systolic blood pressure: systolic blood pressure x low social support interaction (1df test) (PMID: 34734193)',
#  'social deprivation, systolic blood pressure: systolic blood pressure x low social support interaction (2df test) (PMID: 34734193)',
#  'trait in response to lamotrigine, maculopapular eruption, epilepsy: epilepsy and lamotrigine-induced maculopapular eruptions (PMID: 26220383)',
#  'tropical spastic paraparesis: htlv-1 associated myelopathy (PMID: 33649182)'}

# %%
enr_tbl=pd.DataFrame(columns=['trait','parent_trait','network_genes','odds_ratio','p_intersect'])

for p in par:
    #select parent term
    print('analyzing '+p)
    #print([id_to_name[x] for x in nx.predecessor(graph, name_to_id[p],cutoff=2)])
    #print([id_to_name[x] for x in nx.descendants_at_distance(graph, name_to_id[p],2)])
    #print([id_to_name[x] for x in nx.predecessor(graph, name_to_id[p])])
    children=return_descendents_name(graph,id_to_name, name_to_id[p])
    t=set(cat[cat['subject_id'].isin([name_to_id[x] for x in children])]['GENE'].dropna())
    print(len(t))
    odds_ratio, p_intersect, gene_list= calculate_enrichment(t,coloc_dict_cat,p)
    if (len(gene_list)>0):
        enr_tbl = pd.concat([pd.DataFrame([[p, 'mammalian phenotype', gene_list, odds_ratio, p_intersect]], columns=enr_tbl.columns), enr_tbl], ignore_index=True)
# Out:
# analyzing pigmentation phenotype
# 178
# Enrichment of network nodes in genes in the GWAS catalog annotated for pigmentation phenotype: p=0.9589780206968866
# Odds ratio: OD=0.3105858548698611
# Number of annotated genes in PCNet: 132
# Number of annotated genes in network: 1
#
# analyzing neoplasm
# 0
# Enrichment of network nodes in genes in the GWAS catalog annotated for neoplasm: p=1.0
# Odds ratio: OD=nan
# Number of annotated genes in PCNet: 0
# Number of annotated genes in network: 0
#
# analyzing normal phenotype
# 0
# Enrichment of network nodes in genes in the GWAS catalog annotated for normal phenotype: p=1.0
# Odds ratio: OD=nan
# Number of annotated genes in PCNet: 0
# Number of annotated genes in network: 0
#
# analyzing nervous system phenotype
# 669
# Enrichment of network nodes in genes in the GWAS catalog annotated for nervous system phenotype: p=0.2381905234612773
# Odds ratio: OD=1.2963751247090123
# Number of annotated genes in PCNet: 400
# Number of annotated genes in network: 12
#
# analyzing renal/urinary system phenotype
# 405
# Enrichment of network nodes in genes in the GWAS catalog annotated for renal/urinary system phenotype: p=0.2879057287217028
# Odds ratio: OD=1.3028694968553458
# Number of annotated genes in PCNet: 264
# Number of annotated genes in network: 8
#
# analyzing muscle phenotype
# 684
# Enrichment of network nodes in genes in the GWAS catalog annotated for muscle phenotype: p=0.006286586321035302
# Odds ratio: OD=2.0565374749639833
# Number of annotated genes in PCNet: 400
# Number of annotated genes in network: 18
#
# analyzing liver/biliary system phenotype
# 614
# Enrichment of network nodes in genes in the GWAS catalog annotated for liver/biliary system phenotype: p=0.9387786404733942
# Odds ratio: OD=0.5825006751282744
# Number of annotated genes in PCNet: 420
# Number of annotated genes in network: 6
#
# analyzing limbs/digits/tail phenotype
# 67
# Enrichment of network nodes in genes in the GWAS catalog annotated for limbs/digits/tail phenotype: p=0.5889521556939374
# Odds ratio: OD=1.1460843373493976
# Number of annotated genes in PCNet: 37
# Number of annotated genes in network: 1
#
# analyzing adipose tissue phenotype
# 0
# Enrichment of network nodes in genes in the GWAS catalog annotated for adipose tissue phenotype: p=1.0
# Odds ratio: OD=nan
# Number of annotated genes in PCNet: 0
# Number of annotated genes in network: 0
#
# analyzing homeostasis/metabolism phenotype
# 1106
# Enrichment of network nodes in genes in the GWAS catalog annotated for homeostasis/metabolism phenotype: p=0.18615693873115705
# Odds ratio: OD=1.285837837837838
# Number of annotated genes in PCNet: 644
# Number of annotated genes in network: 19
#
# analyzing hearing/vestibular/ear phenotype
# 285
# Enrichment of network nodes in genes in the GWAS catalog annotated for hearing/vestibular/ear phenotype: p=0.8387491476319596
# Odds ratio: OD=0.6480836236933798
# Number of annotated genes in PCNet: 192
# Number of annotated genes in network: 3
#
# analyzing growth/size/body region phenotype
# 2629
# Enrichment of network nodes in genes in the GWAS catalog annotated for growth/size/body region phenotype: p=0.0036046394973027595
# Odds ratio: OD=1.6265740849711663
# Number of annotated genes in PCNet: 1516
# Number of annotated genes in network: 51
#
# analyzing endocrine/exocrine gland phenotype
# 711
# Enrichment of network nodes in genes in the GWAS catalog annotated for endocrine/exocrine gland phenotype: p=0.9274447020123207
# Odds ratio: OD=0.6010012051543525
# Number of annotated genes in PCNet: 408
# Number of annotated genes in network: 6
#
# analyzing embryo phenotype
# 5
# Enrichment of network nodes in genes in the GWAS catalog annotated for embryo phenotype: p=1.0
# Odds ratio: OD=0.0
# Number of annotated genes in PCNet: 3
# Number of annotated genes in network: 0
#
# analyzing digestive/alimentary phenotype
# 884
# Enrichment of network nodes in genes in the GWAS catalog annotated for digestive/alimentary phenotype: p=0.003219996631282098
# Odds ratio: OD=1.9799828424363741
# Number of annotated genes in PCNet: 562
# Number of annotated genes in network: 24
#
# analyzing craniofacial phenotype
# 1143
# Enrichment of network nodes in genes in the GWAS catalog annotated for craniofacial phenotype: p=0.08955376546802866
# Odds ratio: OD=1.414423822571473
# Number of annotated genes in PCNet: 689
# Number of annotated genes in network: 22
#
# analyzing cellular phenotype
# 11
# Enrichment of network nodes in genes in the GWAS catalog annotated for cellular phenotype: p=1.0
# Odds ratio: OD=0.0
# Number of annotated genes in PCNet: 7
# Number of annotated genes in network: 0
#
# analyzing cardiovascular system phenotype
# 5260
# Enrichment of network nodes in genes in the GWAS catalog annotated for cardiovascular system phenotype: p=0.07969559709149959
# Odds ratio: OD=1.2618685283966111
# Number of annotated genes in PCNet: 3274
# Number of annotated genes in network: 87
#
# analyzing behavior/neurological phenotype
# 603
# Enrichment of network nodes in genes in the GWAS catalog annotated for behavior/neurological phenotype: p=0.00677904905411369
# Odds ratio: OD=2.084694835680751
# Number of annotated genes in PCNet: 372
# Number of annotated genes in network: 17
#
# analyzing immune system phenotype
# 2081
# Enrichment of network nodes in genes in the GWAS catalog annotated for immune system phenotype: p=0.8013564845870575
# Odds ratio: OD=0.8526715410573679
# Number of annotated genes in PCNet: 1297
# Number of annotated genes in network: 27
#
# analyzing respiratory system phenotype
# 579
# Enrichment of network nodes in genes in the GWAS catalog annotated for respiratory system phenotype: p=0.18923259861842773
# Odds ratio: OD=1.3917786530738339
# Number of annotated genes in PCNet: 343
# Number of annotated genes in network: 11
#
# analyzing reproductive system phenotype
# 83
# Enrichment of network nodes in genes in the GWAS catalog annotated for reproductive system phenotype: p=0.6610476249013828
# Odds ratio: OD=0.9366100766703176
# Number of annotated genes in PCNet: 45
# Number of annotated genes in network: 1
#
# analyzing skeleton phenotype
# 3488
# Enrichment of network nodes in genes in the GWAS catalog annotated for skeleton phenotype: p=0.761480336938124
# Odds ratio: OD=0.8953892996955198
# Number of annotated genes in PCNet: 2098
# Number of annotated genes in network: 46
#
# analyzing vision/eye phenotype
# 275
# Enrichment of network nodes in genes in the GWAS catalog annotated for vision/eye phenotype: p=0.822585980118331
# Odds ratio: OD=0.6699320271891244
# Number of annotated genes in PCNet: 186
# Number of annotated genes in network: 3
#
# analyzing taste/olfaction phenotype
# 2
# Enrichment of network nodes in genes in the GWAS catalog annotated for taste/olfaction phenotype: p=1.0
# Odds ratio: OD=0.0
# Number of annotated genes in PCNet: 2
# Number of annotated genes in network: 0
#
# analyzing hematopoietic system phenotype
# 140
# Enrichment of network nodes in genes in the GWAS catalog annotated for hematopoietic system phenotype: p=0.8859189798185632
# Odds ratio: OD=0.45999729254095034
# Number of annotated genes in PCNet: 90
# Number of annotated genes in network: 1
#
# analyzing mortality/aging
# 10
# Enrichment of network nodes in genes in the GWAS catalog annotated for mortality/aging: p=1.0
# Odds ratio: OD=0.0
# Number of annotated genes in PCNet: 6
# Number of annotated genes in network: 0
#
# analyzing integument phenotype
# 1350
# Enrichment of network nodes in genes in the GWAS catalog annotated for integument phenotype: p=0.731466872653708
# Odds ratio: OD=0.873283257033646
# Number of annotated genes in PCNet: 761
# Number of annotated genes in network: 16

# %%
enr_tbl.sort_values('p_intersect')
# Out:
#                                  trait         parent_trait  \
# 10      digestive/alimentary phenotype  mammalian phenotype
# 12   growth/size/body region phenotype  mammalian phenotype
# 17                    muscle phenotype  mammalian phenotype
# 7      behavior/neurological phenotype  mammalian phenotype
# 8      cardiovascular system phenotype  mammalian phenotype
# 9               craniofacial phenotype  mammalian phenotype
# 14    homeostasis/metabolism phenotype  mammalian phenotype
# 5         respiratory system phenotype  mammalian phenotype
# 19            nervous system phenotype  mammalian phenotype
# 18      renal/urinary system phenotype  mammalian phenotype
# 15         limbs/digits/tail phenotype  mammalian phenotype
# 4        reproductive system phenotype  mammalian phenotype
# 0                 integument phenotype  mammalian phenotype
# 3                   skeleton phenotype  mammalian phenotype
# 6              immune system phenotype  mammalian phenotype
# 2                 vision/eye phenotype  mammalian phenotype
# 13    hearing/vestibular/ear phenotype  mammalian phenotype
# 1       hematopoietic system phenotype  mammalian phenotype
# 11  endocrine/exocrine gland phenotype  mammalian phenotype
# 16      liver/biliary system phenotype  mammalian phenotype
# 20              pigmentation phenotype  mammalian phenotype
#
#                                         network_genes  odds_ratio  p_intersect
# 10  {SATB2, UBTF, ERBB4, STMN4, ERC1, ZNF800, KIAA...    1.979983     0.003220
# 12  {RGS7, PCSK2, FGFR4, NRXN3, DLGAP1, NETO1, MPP...    1.626574     0.003605
# 17  {CUX2, FOXP1, CSMD1, CHRNA2, TUSC2, SATB2, CAC...    2.056537     0.006287
# 7   {CUX2, FOXP1, RAD51, CSMD1, MYT1, CTXND1, DLGA...    2.084695     0.006779
# 8   {ZDHHC17, ETV1, FOXG1, CPLX1, ZNF800, LRRCC1, ...    1.261869     0.079696
# 9   {FGFR4, NETO1, MPPED2, SHTN1, EHBP1, GRIA1, PT...    1.414424     0.089554
# 14  {AGBL1, POU3F2, KIAA1217, FCRL3, GBGT1, DCC, C...    1.285838     0.186157
# 5   {NKAIN2, NTRK3, CSMD1, TMEM42, BICD1, CAMTA1, ...    1.391779     0.189233
# 19  {CUX2, PCSK2, CSMD1, DSCAML1, ADGRL3, CPNE4, S...    1.296375     0.238191
# 18  {FCRL3, CSMD1, FGFR4, XKR9, CPO, TFAP2B, EBLN1...    1.302869     0.287906
# 15                                            {CSMD1}    1.146084     0.588952
# 4                                             {NCAM1}    0.936610     0.661048
# 0   {NHLRC1, PJA2, CSMD1, KIF1A, FYN, FOXP1, PPP5C...    0.873283     0.731467
# 3   {RGS7, SATB2, DLGAP1, NETO1, MPPED2, PIP4K2C, ...    0.895389     0.761480
# 6   {NKAIN2, STXBP1, SATB2, DLGAP1, PIP4K2C, BLK, ...    0.852672     0.801356
# 2                              {PIK3R1, LAMA2, DOCK9}    0.669932     0.822586
# 13                                 {JMY, DLG4, SOX11}    0.648084     0.838749
# 1                                              {UBTF}    0.459997     0.885919
# 11         {FYN, STXBP1, MARCHF7, SYN2, VEGFA, ASIC2}    0.601001     0.927445
# 16          {FCRL3, CUX2, FGFR4, VPS11, VEGFA, EBLN1}    0.582501     0.938779
# 20                                            {FOXP1}    0.310586     0.958978

# %%
depth=0
enr_tbl['depth']=depth

# %%
enr_concat=enr_tbl

# %%
enr_tbl
# Out:
#                                  trait         parent_trait  \
# 0                 integument phenotype  mammalian phenotype
# 1       hematopoietic system phenotype  mammalian phenotype
# 2                 vision/eye phenotype  mammalian phenotype
# 3                   skeleton phenotype  mammalian phenotype
# 4        reproductive system phenotype  mammalian phenotype
# 5         respiratory system phenotype  mammalian phenotype
# 6              immune system phenotype  mammalian phenotype
# 7      behavior/neurological phenotype  mammalian phenotype
# 8      cardiovascular system phenotype  mammalian phenotype
# 9               craniofacial phenotype  mammalian phenotype
# 10      digestive/alimentary phenotype  mammalian phenotype
# 11  endocrine/exocrine gland phenotype  mammalian phenotype
# 12   growth/size/body region phenotype  mammalian phenotype
# 13    hearing/vestibular/ear phenotype  mammalian phenotype
# 14    homeostasis/metabolism phenotype  mammalian phenotype
# 15         limbs/digits/tail phenotype  mammalian phenotype
# 16      liver/biliary system phenotype  mammalian phenotype
# 17                    muscle phenotype  mammalian phenotype
# 18      renal/urinary system phenotype  mammalian phenotype
# 19            nervous system phenotype  mammalian phenotype
# 20              pigmentation phenotype  mammalian phenotype
#
#                                         network_genes  odds_ratio  \
# 0   {NHLRC1, PJA2, CSMD1, KIF1A, FYN, FOXP1, PPP5C...    0.873283
# 1                                              {UBTF}    0.459997
# 2                              {PIK3R1, LAMA2, DOCK9}    0.669932
# 3   {RGS7, SATB2, DLGAP1, NETO1, MPPED2, PIP4K2C, ...    0.895389
# 4                                             {NCAM1}    0.936610
# 5   {NKAIN2, NTRK3, CSMD1, TMEM42, BICD1, CAMTA1, ...    1.391779
# 6   {NKAIN2, STXBP1, SATB2, DLGAP1, PIP4K2C, BLK, ...    0.852672
# 7   {CUX2, FOXP1, RAD51, CSMD1, MYT1, CTXND1, DLGA...    2.084695
# 8   {ZDHHC17, ETV1, FOXG1, CPLX1, ZNF800, LRRCC1, ...    1.261869
# 9   {FGFR4, NETO1, MPPED2, SHTN1, EHBP1, GRIA1, PT...    1.414424
# 10  {SATB2, UBTF, ERBB4, STMN4, ERC1, ZNF800, KIAA...    1.979983
# 11         {FYN, STXBP1, MARCHF7, SYN2, VEGFA, ASIC2}    0.601001
# 12  {RGS7, PCSK2, FGFR4, NRXN3, DLGAP1, NETO1, MPP...    1.626574
# 13                                 {JMY, DLG4, SOX11}    0.648084
# 14  {AGBL1, POU3F2, KIAA1217, FCRL3, GBGT1, DCC, C...    1.285838
# 15                                            {CSMD1}    1.146084
# 16          {FCRL3, CUX2, FGFR4, VPS11, VEGFA, EBLN1}    0.582501
# 17  {CUX2, FOXP1, CSMD1, CHRNA2, TUSC2, SATB2, CAC...    2.056537
# 18  {FCRL3, CSMD1, FGFR4, XKR9, CPO, TFAP2B, EBLN1...    1.302869
# 19  {CUX2, PCSK2, CSMD1, DSCAML1, ADGRL3, CPNE4, S...    1.296375
# 20                                            {FOXP1}    0.310586
#
#     p_intersect  depth
# 0      0.731467      0
# 1      0.885919      0
# 2      0.822586      0
# 3      0.761480      0
# 4      0.661048      0
# 5      0.189233      0
# 6      0.801356      0
# 7      0.006779      0
# 8      0.079696      0
# 9      0.089554      0
# 10     0.003220      0
# 11     0.927445      0
# 12     0.003605      0
# 13     0.838749      0
# 14     0.186157      0
# 15     0.588952      0
# 16     0.938779      0
# 17     0.006287      0
# 18     0.287906      0
# 19     0.238191      0
# 20     0.958978      0

# %%
t=enr_tbl
plt.scatter(x=enr_tbl.odds_ratio,y=-np.log10(enr_tbl.p_intersect))
plt.xlabel('odds ratio')
plt.ylabel('-log10(p-value)')
plt.axhline(-np.log10(0.05/len(par)),color='black',ls=':',label='bonferroni')

texts = []
for i in t.index:
    if (t.p_intersect[i]<(0.05/len(enr_tbl))):
        texts.append(plt.annotate(t.trait[i], (t.odds_ratio[i], -np.log10(t.p_intersect[i]))))

# Adjust text to avoid overlap
adjust_text(texts, only_move={'points': 'y', 'texts': 'y'}, 
            arrowprops=dict(arrowstyle="->", color='black', lw=0.5))


plt.show()

# %% [markdown]
# enrichments look very odd... not sure why
