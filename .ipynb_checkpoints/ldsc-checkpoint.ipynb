# %%
library(GenomicSEM)
library(here)
# Out:
# Warning message:
# “replacing previous import ‘gdata::nobs’ by ‘lavaan::nobs’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::first’ by ‘data.table::first’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::last’ by ‘data.table::last’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::resample’ by ‘R.utils::resample’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::env’ by ‘R.utils::env’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘data.table::first’ by ‘dplyr::first’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::arrange’ by ‘dplyr::arrange’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::count’ by ‘dplyr::count’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::desc’ by ‘dplyr::desc’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::summarise’ by ‘dplyr::summarise’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::id’ by ‘dplyr::id’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::rename’ by ‘dplyr::rename’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::summarize’ by ‘dplyr::summarize’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘data.table::last’ by ‘dplyr::last’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘data.table::between’ by ‘dplyr::between’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::combine’ by ‘dplyr::combine’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::starts_with’ by ‘dplyr::starts_with’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::failwith’ by ‘dplyr::failwith’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘plyr::mutate’ by ‘dplyr::mutate’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘Rcpp::.DollarNames’ by ‘utils::.DollarNames’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘Matrix::tail’ by ‘utils::tail’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘gdata::object.size’ by ‘utils::object.size’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘Rcpp::prompt’ by ‘utils::prompt’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘Matrix::head’ by ‘utils::head’ when loading ‘GenomicSEM’”
# Warning message:
# “replacing previous import ‘R.utils::timestamp’ by ‘utils::timestamp’ when loading ‘GenomicSEM’”
# here() starts at /tscc/projects/ps-palmer/brittany/SUD_cross_species/scripts

# %%
getwd()
rename_files=FALSE
# Out:
# [1] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/scripts"

# %%
setwd('/tscc/projects/ps-palmer/brittany/SUD_cross_species/')
munged.dir <- here("/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr")
ld.dir <- here("/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_ldsc/ld_scores_wchr")
wld.dir <- here("/tscc/projects/ps-palmer/brittany/SUD_cross_species/ldsc/ld_scores_wchr")

# %%
#rename files to make them function in LDSC package
rename files=FALSE
ldscore_files <- list.files(ld.dir, full.names = TRUE)
#remove ldsc_5Mb_chr from file name
new_names <- substring(basename(ldscore_files), 13)
new_file_paths <- file.path(dirname(ldscore_files), new_names)
if (rename_files)
    {file.rename(ldscore_files, new_file_paths)}

# %%
trait_names=trait_names[trait_names!= 'regressedlr_nicsa_day1_infusion']
traits=traits[traits!='/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz']

# %%
traits
# Out:
#  [1] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz"
#  [2] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz"
#  [3] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz"
#  [4] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz"
#  [5] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz"
#  [6] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz"
#  [7] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz"
#  [8] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz"
#  [9] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz"
# [10] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz"
# [11] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz"
# [12] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz"
# [13] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz"
# [14] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz"
# [15] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz"
# [16] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz"
# [17] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz"
# [18] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz"
# [19] "/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz"

# %%
# run multivariate ldsc

#traits point to munged data
trait_tbl=read.table(here('nicsa_munge_ref/nicsa_traits.csv'),sep=',',header=1)
trait_names=sort(trait_tbl$file_prefix)
traits <- sort(list.files(munged.dir, pattern = "\\.gz$", full.names=TRUE))

sample.prev <- rep(NA, length(traits))
population.prev <- rep(NA, length(traits))

LDSCoutput <- ldsc(traits = traits, sample.prev = sample.prev, population.prev = population.prev, ld = ld.dir, wld = wld.dir, trait.names = trait_names, chr = 20)

save(LDSCoutput, file="nicsa_LD_score_regression/LDSCoutput_rerun.RData")
# Out:
# Multivariate ld-score regression of 19 traits (/tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz) began at: 2024-03-18 14:02:30.966052
# Setting the number of blocks used to perform the block jacknife used to estimate the sampling covariance matrix (V) to 211
# This reflects the need to estimate V using at least one more block then their are nonredundant elements in the genetic covariance matrix that includes individual SNPs.
# If the n.blocks is > 1000 you should carefully inspect output for any strange results, such as extremely significant Q_SNP estimates.
# Reading in LD scores
# Read in summary statistics [1/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [2/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [3/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [4/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [5/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [6/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [7/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [8/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [9/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [10/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [11/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [12/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [13/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [14/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [15/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [16/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [17/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [18/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Read in summary statistics [19/19] from: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Out of 5340180 SNPs, 5336522 remain after merging with LD-score files
# Removing 0 SNPs with Chi^2 > 80; 5336522 remain
# Estimating heritability [1/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.3816
# Lambda GC: 1.3569
# Intercept: 1.1448 (0.0701)
# Ratio: 0.3795 (0.1838)
# Total Observed Scale h2: 0.1281 (0.0482)
# h2 Z: 2.66
# Calculating genetic covariance [2/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz
# Mean Z*Z: 0.5043
# Cross trait Intercept: 0.3553 (0.0472)
# Total Observed Scale Genetic Covariance (g_cov): 0.0755 (0.0348)
# g_cov Z: 2.17
# g_cov P-value: 0.029997
# Calculating genetic covariance [3/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz
# Mean Z*Z: 0.8841
# Cross trait Intercept: 0.7661 (0.0681)
# Total Observed Scale Genetic Covariance (g_cov): 0.0605 (0.0431)
# g_cov Z: 1.4
# g_cov P-value: 0.16071
# Calculating genetic covariance [4/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz
# Mean Z*Z: 0.6607
# Cross trait Intercept: 0.5735 (0.0608)
# Total Observed Scale Genetic Covariance (g_cov): 0.0519 (0.0418)
# g_cov Z: 1.24
# g_cov P-value: 0.21349
# Calculating genetic covariance [5/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz
# Mean Z*Z: 0.9909
# Cross trait Intercept: 0.8118 (0.0711)
# Total Observed Scale Genetic Covariance (g_cov): 0.0965 (0.0485)
# g_cov Z: 1.99
# g_cov P-value: 0.046693
# Calculating genetic covariance [6/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz
# Mean Z*Z: 0.7444
# Cross trait Intercept: 0.6765 (0.056)
# Total Observed Scale Genetic Covariance (g_cov): 0.0302 (0.0373)
# g_cov Z: 0.809
# g_cov P-value: 0.41825
# Calculating genetic covariance [7/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz
# Mean Z*Z: 0.9138
# Cross trait Intercept: 0.7491 (0.0658)
# Total Observed Scale Genetic Covariance (g_cov): 0.087 (0.0446)
# g_cov Z: 1.95
# g_cov P-value: 0.051468
# Calculating genetic covariance [8/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz
# Mean Z*Z: 0.955
# Cross trait Intercept: 0.7628 (0.054)
# Total Observed Scale Genetic Covariance (g_cov): 0.0982 (0.0389)
# g_cov Z: 2.52
# g_cov P-value: 0.011625
# Calculating genetic covariance [9/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz
# Mean Z*Z: 0.9715
# Cross trait Intercept: 0.701 (0.0606)
# Total Observed Scale Genetic Covariance (g_cov): 0.1501 (0.0445)
# g_cov Z: 3.37
# g_cov P-value: 0.00073826
# Calculating genetic covariance [10/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz
# Mean Z*Z: 0.6753
# Cross trait Intercept: 0.4162 (0.0477)
# Total Observed Scale Genetic Covariance (g_cov): 0.1224 (0.0371)
# g_cov Z: 3.3
# g_cov P-value: 0.00096172
# Calculating genetic covariance [11/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz
# Mean Z*Z: 0.6334
# Cross trait Intercept: 0.4396 (0.0507)
# Total Observed Scale Genetic Covariance (g_cov): 0.0882 (0.0362)
# g_cov Z: 2.44
# g_cov P-value: 0.014758
# Calculating genetic covariance [12/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz
# Mean Z*Z: 0.786
# Cross trait Intercept: 0.6976 (0.053)
# Total Observed Scale Genetic Covariance (g_cov): 0.0404 (0.0328)
# g_cov Z: 1.23
# g_cov P-value: 0.21871
# Calculating genetic covariance [13/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz
# Mean Z*Z: 0.9794
# Cross trait Intercept: 0.7741 (0.0551)
# Total Observed Scale Genetic Covariance (g_cov): 0.1017 (0.037)
# g_cov Z: 2.75
# g_cov P-value: 0.0060258
# Calculating genetic covariance [14/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz
# Mean Z*Z: 0.9846
# Cross trait Intercept: 0.7815 (0.0654)
# Total Observed Scale Genetic Covariance (g_cov): 0.107 (0.0424)
# g_cov Z: 2.53
# g_cov P-value: 0.011502
# Calculating genetic covariance [15/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# Mean Z*Z: 0.9634
# Cross trait Intercept: 0.8156 (0.0529)
# Total Observed Scale Genetic Covariance (g_cov): 0.0804 (0.0365)
# g_cov Z: 2.2
# g_cov P-value: 0.027466
# Calculating genetic covariance [16/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# Mean Z*Z: 0.9058
# Cross trait Intercept: 0.7598 (0.0545)
# Total Observed Scale Genetic Covariance (g_cov): 0.0808 (0.0381)
# g_cov Z: 2.12
# g_cov P-value: 0.033959
# Calculating genetic covariance [17/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# Mean Z*Z: 0.99
# Cross trait Intercept: 0.8091 (0.0572)
# Total Observed Scale Genetic Covariance (g_cov): 0.0917 (0.0405)
# g_cov Z: 2.27
# g_cov P-value: 0.023473
# Calculating genetic covariance [18/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Mean Z*Z: 0.9779
# Cross trait Intercept: 0.8251 (0.0584)
# Total Observed Scale Genetic Covariance (g_cov): 0.0797 (0.0398)
# g_cov Z: 2
# g_cov P-value: 0.045036
# Calculating genetic covariance [19/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_all_days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Z*Z: 1.3566
# Cross trait Intercept: 1.0641 (0.0712)
# Total Observed Scale Genetic Covariance (g_cov): 0.1596 (0.0512)
# g_cov Z: 3.12
# g_cov P-value: 0.0018186
# Estimating heritability [20/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.2101
# Lambda GC: 1.2724
# Intercept: 1.17 (0.0637)
# Ratio: 0.8091 (0.3029)
# Total Observed Scale h2: 0.0157 (0.0442)
# h2 Z: 0.355
# Calculating genetic covariance [21/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_last_three_median.sumstats.gz
# Mean Z*Z: 0.4264
# Cross trait Intercept: 0.3137 (0.0474)
# Total Observed Scale Genetic Covariance (g_cov): 0.0563 (0.0342)
# g_cov Z: 1.64
# g_cov P-value: 0.10034
# Calculating genetic covariance [22/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_active_inactive_ratio.sumstats.gz
# Mean Z*Z: 0.8518
# Cross trait Intercept: 0.7736 (0.0558)
# Total Observed Scale Genetic Covariance (g_cov): 0.0382 (0.0402)
# g_cov Z: 0.951
# g_cov P-value: 0.34145
# Calculating genetic covariance [23/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_activelick.sumstats.gz
# Mean Z*Z: 0.694
# Cross trait Intercept: 0.577 (0.056)
# Total Observed Scale Genetic Covariance (g_cov): 0.0566 (0.0378)
# g_cov Z: 1.5
# g_cov P-value: 0.1342
# Calculating genetic covariance [24/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day1_infusion.sumstats.gz
# Mean Z*Z: 0.3951
# Cross trait Intercept: 0.3925 (0.0483)
# Total Observed Scale Genetic Covariance (g_cov): -0.0072 (0.0328)
# g_cov Z: -0.22
# g_cov P-value: 0.826
# Calculating genetic covariance [25/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_active_inactive_ratio.sumstats.gz
# Mean Z*Z: 0.5784
# Cross trait Intercept: 0.4406 (0.0487)
# Total Observed Scale Genetic Covariance (g_cov): 0.0708 (0.0385)
# g_cov Z: 1.84
# g_cov P-value: 0.065739
# Calculating genetic covariance [26/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_activelick.sumstats.gz
# Mean Z*Z: 0.2548
# Cross trait Intercept: 0.1149 (0.0494)
# Total Observed Scale Genetic Covariance (g_cov): 0.0677 (0.0382)
# g_cov Z: 1.77
# g_cov P-value: 0.076165
# Calculating genetic covariance [27/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_day10_infusion.sumstats.gz
# Mean Z*Z: 0.6894
# Cross trait Intercept: 0.5109 (0.0475)
# Total Observed Scale Genetic Covariance (g_cov): 0.0959 (0.0387)
# g_cov Z: 2.48
# g_cov P-value: 0.013141
# Calculating genetic covariance [28/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_median.sumstats.gz
# Mean Z*Z: 0.8436
# Cross trait Intercept: 0.7185 (0.0507)
# Total Observed Scale Genetic Covariance (g_cov): 0.0554 (0.0385)
# g_cov Z: 1.44
# g_cov P-value: 0.15002
# Calculating genetic covariance [29/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_activelick_total.sumstats.gz
# Mean Z*Z: 0.6743
# Cross trait Intercept: 0.559 (0.0501)
# Total Observed Scale Genetic Covariance (g_cov): 0.0504 (0.0375)
# g_cov Z: 1.35
# g_cov P-value: 0.17852
# Calculating genetic covariance [30/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_median.sumstats.gz
# Mean Z*Z: 0.3381
# Cross trait Intercept: 0.3002 (0.047)
# Total Observed Scale Genetic Covariance (g_cov): 0.0115 (0.0312)
# g_cov Z: 0.369
# g_cov P-value: 0.71206
# Calculating genetic covariance [31/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_first_three_days_infusion_total.sumstats.gz
# Mean Z*Z: 0.3073
# Cross trait Intercept: 0.1766 (0.0492)
# Total Observed Scale Genetic Covariance (g_cov): 0.0605 (0.0366)
# g_cov Z: 1.65
# g_cov P-value: 0.098374
# Calculating genetic covariance [32/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz
# Mean Z*Z: 0.5406
# Cross trait Intercept: 0.3767 (0.0477)
# Total Observed Scale Genetic Covariance (g_cov): 0.0828 (0.0356)
# g_cov Z: 2.32
# g_cov P-value: 0.020232
# Calculating genetic covariance [33/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# Mean Z*Z: 0.3183
# Cross trait Intercept: 0.2264 (0.0448)
# Total Observed Scale Genetic Covariance (g_cov): 0.0442 (0.0347)
# g_cov Z: 1.27
# g_cov P-value: 0.20303
# Calculating genetic covariance [34/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# Mean Z*Z: 0.2619
# Cross trait Intercept: 0.2338 (0.0426)
# Total Observed Scale Genetic Covariance (g_cov): 0.0115 (0.0322)
# g_cov Z: 0.355
# g_cov P-value: 0.72239
# Calculating genetic covariance [35/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_active_inactive_ratio_first_three_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# ...
# Mean Z*Z: 0.4926
# Cross trait Intercept: 0.405 (0.0515)
# Total Observed Scale Genetic Covariance (g_cov): 0.0436 (0.0369)
# g_cov Z: 1.18
# g_cov P-value: 0.23728
# Calculating genetic covariance [175/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Z*Z: 0.9737
# Cross trait Intercept: 0.7242 (0.0651)
# Total Observed Scale Genetic Covariance (g_cov): 0.1337 (0.0449)
# g_cov Z: 2.98
# g_cov P-value: 0.0029259
# Estimating heritability [176/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.3316
# Lambda GC: 1.2969
# Intercept: 1.1279 (0.0577)
# Ratio: 0.3859 (0.1739)
# Total Observed Scale h2: 0.1108 (0.042)
# h2 Z: 2.64
# Calculating genetic covariance [177/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# Mean Z*Z: 1.0955
# Cross trait Intercept: 0.9029 (0.0544)
# Total Observed Scale Genetic Covariance (g_cov): 0.1045 (0.0386)
# g_cov Z: 2.71
# g_cov P-value: 0.0068274
# Calculating genetic covariance [178/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# Mean Z*Z: 1.2375
# Cross trait Intercept: 0.9962 (0.0569)
# Total Observed Scale Genetic Covariance (g_cov): 0.1266 (0.0438)
# g_cov Z: 2.89
# g_cov P-value: 0.0038369
# Calculating genetic covariance [179/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Mean Z*Z: 1.1106
# Cross trait Intercept: 0.9159 (0.0552)
# Total Observed Scale Genetic Covariance (g_cov): 0.103 (0.0385)
# g_cov Z: 2.68
# g_cov P-value: 0.0073807
# Calculating genetic covariance [180/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_activelick_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Z*Z: 0.9669
# Cross trait Intercept: 0.7748 (0.0542)
# Total Observed Scale Genetic Covariance (g_cov): 0.1049 (0.039)
# g_cov Z: 2.69
# g_cov P-value: 0.0072252
# Estimating heritability [181/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.3167
# Lambda GC: 1.3623
# Intercept: 1.1298 (0.0629)
# Ratio: 0.4098 (0.1986)
# Total Observed Scale h2: 0.1036 (0.0399)
# h2 Z: 2.6
# Calculating genetic covariance [182/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# Mean Z*Z: 1.0932
# Cross trait Intercept: 0.8553 (0.0556)
# Total Observed Scale Genetic Covariance (g_cov): 0.1257 (0.0403)
# g_cov Z: 3.12
# g_cov P-value: 0.0018345
# Calculating genetic covariance [183/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Mean Z*Z: 1.2366
# Cross trait Intercept: 1.0598 (0.0608)
# Total Observed Scale Genetic Covariance (g_cov): 0.0969 (0.0385)
# g_cov Z: 2.52
# g_cov P-value: 0.011769
# Calculating genetic covariance [184/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_median.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Z*Z: 0.9268
# Cross trait Intercept: 0.7306 (0.0547)
# Total Observed Scale Genetic Covariance (g_cov): 0.1077 (0.04)
# g_cov Z: 2.69
# g_cov P-value: 0.0071517
# Estimating heritability [185/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.3966
# Lambda GC: 1.3695
# Intercept: 1.1528 (0.0658)
# Ratio: 0.3853 (0.1659)
# Total Observed Scale h2: 0.1226 (0.0503)
# h2 Z: 2.44
# Calculating genetic covariance [186/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Mean Z*Z: 1.1941
# Cross trait Intercept: 0.975 (0.0601)
# Total Observed Scale Genetic Covariance (g_cov): 0.1108 (0.043)
# g_cov Z: 2.58
# g_cov P-value: 0.010004
# Calculating genetic covariance [187/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_last_three_days_infusion_total.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Z*Z: 0.956
# Cross trait Intercept: 0.712 (0.0571)
# Total Observed Scale Genetic Covariance (g_cov): 0.1264 (0.0427)
# g_cov Z: 2.96
# g_cov P-value: 0.003053
# Estimating heritability [188/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.3602
# Lambda GC: 1.3539
# Intercept: 1.1877 (0.0649)
# Ratio: 0.521 (0.1801)
# Total Observed Scale h2: 0.0908 (0.0421)
# h2 Z: 2.16
# Calculating genetic covariance [189/190] for traits: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# 5336522 SNPs remain after merging /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz summary statistics
# Results for genetic covariance between: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_activelick_10days.sumstats.gz and /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Z*Z: 0.9592
# Cross trait Intercept: 0.747 (0.0586)
# Total Observed Scale Genetic Covariance (g_cov): 0.1121 (0.0418)
# g_cov Z: 2.68
# g_cov P-value: 0.0072901
# Estimating heritability [190/190] for: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Heritability Results for trait: /tscc/projects/ps-palmer/brittany/SUD_cross_species/nicsa_munge/nicsa_munge_wchr/regressedlr_nicsa_total_infusion_10days.sumstats.gz
# Mean Chi^2 across remaining SNPs: 1.465
# Lambda GC: 1.4413
# Intercept: 1.0991 (0.0746)
# Ratio: 0.2131 (0.1604)
# Total Observed Scale h2: 0.2009 (0.0563)
# h2 Z: 3.57
# Warning message in ldsc(traits = traits, sample.prev = sample.prev, population.prev = population.prev, :
# “Your genetic covariance matrix includes traits estimated to have a negative heritability.”
# Genetic correlation results could not be computed due to negative heritability estimates.
# LDSC finished running at 2024-03-18 14:25:59.206074
# Running LDSC for all files took 23 minutes and 28 seconds

# %%
write.table(LDSCoutput$S, "nicsa_LD_score_regression/S.tsv",sep='\t')
write.table(LDSCoutput$V, "nicsa_LD_score_regression/V.tsv",sep='\t')
write.table(LDSCoutput$I, "nicsa_LD_score_regression/I.tsv",sep='\t')
write.table(LDSCoutput$N, "nicsa_LD_score_regression/N.tsv",sep='\t')
write.table(LDSCoutput$m, "nicsa_LD_score_regression/m.tsv",sep='\t')

# %%
sample.prev <- rep(NA, length(traits))
population.prev <- rep(NA, length(traits))

LDSCoutput <- ldsc(traits = traits, sample.prev = sample.prev, population.prev = population.prev, ld = ld.dir, wld = wld.dir, trait.names = trait_names, chr = 20)

save(LDSCoutput, file="nicsa_LD_score_regression/LDSCoutput_rerun.RData")
