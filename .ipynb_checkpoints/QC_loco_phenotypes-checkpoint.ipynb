# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
PRE = "/tscc/projects/ps-palmer/brittany/rat_genomics_paper_pipeline_2024"
OUTPUT = PRE+"/output"
PREDICT_PREF="loco_meta_7k"
MODEL_TISSUE="IL"
PREDICTION=OUTPUT+"/{MODEL_TISSUE}-filtered-{PREDICT_PREF}_predict.txt"
PHENOTYPES=PRE+"/data/phenotype/combined_loco_trait_7k_sorted.fam"
TRAIT="locomotor_activity"
TBL_OUT=OUTPUT+'/'+PREDICT_PREF+'_'+MODEL_TISSUE+'.tsv'

# %%
pheno=pd.read_csv(PHENOTYPES, sep='\t',header=None)
pheno.columns=['fid','rfid','loco']

# %%
pheno
# Out:
#                   fid             rfid      loco
# 0     933000320045877  933000320045877 -0.628241
# 1     933000320045878  933000320045878 -0.488571
# 2     933000320045880  933000320045880  0.216710
# 3     933000320045883  933000320045883  3.044497
# 4     933000320045885  933000320045885  0.071954
# ...               ...              ...       ...
# 7717       00077E9536       00077E9536  0.766547
# 7718       00077E99D8       00077E99D8  1.175479
# 7719       00077E9B37       00077E9B37 -2.139801
# 7720       00077E9B75       00077E9B75  0.545711
# 7721       00077E9BC4       00077E9BC4 -1.715597
#
# [7722 rows x 3 columns]

# %%
meta_data=pd.read_csv('/tscc/projects/ps-palmer/gwas/databases/pedigree/merged_wfu_samplemetadata_colony_of_origin.csv')

# %%
meta_data
# Out:
#                              sample_id               library             rfid  \
# 0            Riptide01_933000120117306             Riptide01  933000120117306
# 1            Riptide01_933000120117307             Riptide01  933000120117307
# 2            Riptide01_933000120117311             Riptide01  933000120117311
# 3            Riptide01_933000120117312             Riptide01  933000120117312
# 4            Riptide01_933000120117313             Riptide01  933000120117313
# ...                                ...                   ...              ...
# 15115  P50_Riptide_Oct_2017_00077EAA6C  P50_Riptide_Oct_2017       00077EAA6C
# 15116  P50_Riptide_Oct_2017_00077EAAE4  P50_Riptide_Oct_2017       00077EAAE4
# 15117  P50_Riptide_Oct_2017_00077EAC01  P50_Riptide_Oct_2017       00077EAC01
# 15118  P50_Riptide_Oct_2017_00077EAF65  P50_Riptide_Oct_2017       00077EAF65
# 15119  P50_Riptide_Oct_2017_00078A1795  P50_Riptide_Oct_2017       00078A1795
#
#                      project_name   barcode  pcr_barcode  \
# 0      u01_olivier_george_cocaine  TGCACTAG          8.0
# 1      u01_olivier_george_cocaine  CGTAGCAT          8.0
# 2      u01_olivier_george_cocaine  CACTAGAC          8.0
# 3      u01_olivier_george_cocaine  TGGTCATG          8.0
# 4      u01_olivier_george_cocaine  GCTTAACG          8.0
# ...                           ...       ...          ...
# 15115           p50_hao_chen_2014  TCGAGTTG          3.0
# 15116           p50_hao_chen_2014  ACACGTGT          3.0
# 15117           p50_hao_chen_2014  CTTCCAAC          3.0
# 15118           p50_hao_chen_2014  TGACCACA          3.0
# 15119           p50_hao_chen_2014  CTTCCATG          3.0
#
#                                runid seq_method pipeline_version  \
# 0      200221_A00953_0069_BH5T5LDSXY      lcWGS    Hybrid_v1.0.0
# 1      200221_A00953_0069_BH5T5LDSXY      lcWGS    Hybrid_v1.0.0
# 2      200221_A00953_0069_BH5T5LDSXY      lcWGS    Hybrid_v1.0.0
# 3      200221_A00953_0069_BH5T5LDSXY      lcWGS    Hybrid_v1.0.0
# 4      200221_A00953_0069_BH5T5LDSXY      lcWGS    Hybrid_v1.0.0
# ...                              ...        ...              ...
# 15115           P50_Riptide_Oct_2017      lcWGS    Hybrid_v1.0.0
# 15116           P50_Riptide_Oct_2017      lcWGS    Hybrid_v1.0.0
# 15117           P50_Riptide_Oct_2017      lcWGS    Hybrid_v1.0.0
# 15118           P50_Riptide_Oct_2017      lcWGS    Hybrid_v1.0.0
# 15119           P50_Riptide_Oct_2017      lcWGS    Hybrid_v1.0.0
#
#        pipeline_round  ... qc_heterozygosity qc_all duplicate_rfid  \
# 0                10.1  ...              pass   pass              0
# 1                10.1  ...              pass   pass              0
# 2                10.1  ...              pass   pass              0
# 3                10.1  ...              pass   pass              0
# 4                10.1  ...              pass   pass              0
# ...               ...  ...               ...    ...            ...
# 15115            10.1  ...              pass   pass              1
# 15116            10.1  ...              pass   pass              1
# 15117            10.1  ...              pass   pass              1
# 15118            10.1  ...              pass   pass              1
# 15119            10.1  ...              pass   pass              1
#
#       times_genotyped times_passed times_failed  sample_use  \
# 0                   1            1            0    analysis
# 1                   1            1            0    analysis
# 2                   1            1            0    analysis
# 3                   1            1            0    analysis
# 4                   1            1            0    analysis
# ...               ...          ...          ...         ...
# 15115               2            2            0    analysis
# 15116               2            2            0    analysis
# 15117               2            2            0    analysis
# 15118               2            2            0    analysis
# 15119               2            2            0    analysis
#
#                                         origin_colony  apurva_exptrack  \
# 0      WFU: NMcwiWFsm:HS #13673907, RRID:RGD_13673907              NaN
# 1      WFU: NMcwiWFsm:HS #13673907, RRID:RGD_13673907              NaN
# 2      WFU: NMcwiWFsm:HS #13673907, RRID:RGD_13673907              NaN
# 3      WFU: NMcwiWFsm:HS #13673907, RRID:RGD_13673907              NaN
# 4      WFU: NMcwiWFsm:HS #13673907, RRID:RGD_13673907              NaN
# ...                                               ...              ...
# 15115                                         MISSING              NaN
# 15116                                         MISSING              NaN
# 15117                                         MISSING              NaN
# 15118                                         MISSING              NaN
# 15119                          UTHSC: Chen_pending:HS            brain
#
#         final_dob
# 0      2017-05-22
# 1      2017-05-21
# 2      2017-05-22
# 3      2017-05-22
# 4      2017-05-30
# ...           ...
# 15115  2015-04-13
# 15116  2015-04-21
# 15117  2015-04-21
# 15118  2015-04-18
# 15119  2016-06-05
#
# [15120 rows x 36 columns]

# %%
tbl=pheno.merge(meta_data[['rfid','project_name','sex']], on='rfid',how='left')
tbl=tbl.sort_values('project_name')

# %%
set(tbl.project_name)
# Out:
# {'p50_david_dietz_2020',
#  'p50_hao_chen_2014',
#  'p50_hao_chen_2020',
#  'p50_hao_chen_2020_rnaseq',
#  'p50_paul_meyer_2014',
#  'p50_shelly_flagel_2014',
#  'pilot_fransesca_telese_twas',
#  'u01_peter_kalivas_italy',
#  'u01_peter_kalivas_us',
#  'u01_suzanne_mitchell',
#  'u01_tom_jhou'}

# %%
fig=sns.boxplot(x = tbl['project_name'], 
            y = tbl['loco'], 
            hue = tbl['project_name'])
fig.set_xticklabels(fig.get_xticklabels(), rotation=90)
# Out:
# /tmp/ipykernel_2784257/3750868829.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   fig.set_xticklabels(fig.get_xticklabels(), rotation=90)
# [Text(0, 0, 'p50_david_dietz_2020'),
#  Text(1, 0, 'p50_hao_chen_2014'),
#  Text(2, 0, 'p50_hao_chen_2020'),
#  Text(3, 0, 'p50_hao_chen_2020_rnaseq'),
#  Text(4, 0, 'p50_paul_meyer_2014'),
#  Text(5, 0, 'p50_shelly_flagel_2014'),
#  Text(6, 0, 'pilot_fransesca_telese_twas'),
#  Text(7, 0, 'u01_peter_kalivas_italy'),
#  Text(8, 0, 'u01_peter_kalivas_us'),
#  Text(9, 0, 'u01_suzanne_mitchell'),
#  Text(10, 0, 'u01_tom_jhou')]

# %%
medians = tbl.groupby(['project_name'])['loco'].median()
vertical_offset = medians['loco'].median() * 0.05 # offset from median for display

for xtick in fig.get_xticks():
    fig.text(xtick,medians[xtick] + vertical_offset,medians[xtick], 
            horizontalalignment='center',size='x-small',color='w',weight='semibold')
