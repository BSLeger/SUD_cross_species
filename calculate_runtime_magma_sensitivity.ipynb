# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###

# %%
25/66*100
# Out:
# 1.5257575757575756

# %%
38/250
# Out:
# 0.152

# %%
x=[0,1,5,10,25,50,100,250]
y=[1,1.33,1.5,2.12,2.8,4.75,9,25/66*100]

# %%
plt.scatter(x,y)

# %%
win=[100,250,500,750,1000]
[0.125*f+1 for f in win]
# Out:
# [13.5, 32.25, 63.5, 94.75, 126.0]
