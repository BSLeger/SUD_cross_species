# %%
import pandas as pd
import os

# %%
os.chdir('/tscc/projects/ps-palmer/brittany/SUD_cross_species/')

# %%
V = pd.read_csv('nicsa_LD_score_regression/V.tsv',sep='\t')
S = pd.read_csv('nicsa_LD_score_regression/S.tsv',sep='\t')

# %%
S.index=S.columns

# %%
S
# Out:
#                                                     regressedlr_nicsa_active_inactive_ratio_all_days  \
# regressedlr_nicsa_active_inactive_ratio_all_days                                            0.128091
# regressedlr_nicsa_active_inactive_ratio_first_t...                                          0.075517
# regressedlr_nicsa_active_inactive_ratio_last_th...                                          0.060515
# regressedlr_nicsa_day1_active_inactive_ratio                                                0.051942
# regressedlr_nicsa_day1_activelick                                                           0.096546
# regressedlr_nicsa_day1_infusion                                                             0.030158
# regressedlr_nicsa_day10_active_inactive_ratio                                               0.086952
# regressedlr_nicsa_day10_activelick                                                          0.098152
# ...
